# %%
import sys
sys.path.append('..')

# %%
import warnings
import multiprocessing
warnings.filterwarnings("ignore", category=ResourceWarning)

# Also suppress multiprocessing warnings
import sys
import os
os.environ['PYTHONWARNINGS'] = 'ignore::ResourceWarning'

# %% [markdown]
# # Data Loading

# %%
from pathlib import Path
import pandas as pd

def load_datasets(data_root: str | Path = "data",
                  tasks: tuple[str, ...] = ("binary", "multiclass"),
                  splits: tuple[str, ...] = ("train", "val", "test")) -> dict:

    data_root = Path(data_root)
    datasets  = {}

    for task in tasks:
        task_dir     = data_root / task
        task_dict    = {}

        for split in splits:
            split_dict = {}
            for kind in ("X", "y"):
                file_path = task_dir / f"{kind}_{split}.pkl"
                split_dict[kind] = pd.read_pickle(file_path)
            task_dict[split] = split_dict

        datasets[task] = task_dict

    return datasets

# %%
from typing import Tuple, Literal
import pandas as pd

def load_split(
    preprocessing_type: Literal["cleaned_only", "full_process"],
    sampling_method: Literal["undersampled", "oversampled"],
    classification_type: Literal["binary", "multiclass"]
) -> Tuple[
    Tuple[pd.DataFrame, pd.Series],  # train: (X_train, y_train)
    Tuple[pd.DataFrame, pd.Series],  # val: (X_val, y_val)
    Tuple[pd.DataFrame, pd.Series]   # test: (X_test, y_test)
]:
    """
    Load different types of splits from the data
    
    Args:
        preprocessing_type: must be "cleaned_only" or "full_process"
        sampling_method: must be "undersampled" or "oversampled"
        classification_type: must be "binary" or "multiclass"
    
    Returns:
        Tuple of (train, val, test) splits, where each split is (X, y)
        - train: (X_train, y_train)
        - val: (X_val, y_val)  
        - test: (X_test, y_test)
    """
    dataset = load_datasets(
        f"../data/{preprocessing_type}/{sampling_method}")[classification_type]
    split_names = ["train", "val", "test"]

    return tuple([(lambda split: (dataset[split]["X"], dataset[split]["y"]))(split) for split in split_names])

# %% [markdown]
# # Experiments

# %%
def combine_text(X):
    X = X.copy()

    combined = X["resume_text"].astype(
        str) + " [SEP] " + X["job_description_text"].astype(str)

    return combined.values

# %%
splits = load_split(preprocessing_type="cleaned_only", sampling_method="undersampled", classification_type="binary")

# %%
SEED = 42

# %% [markdown]
# # Experiment 1: Base Parameters

# %%
from utils import ExperimentManager, Experiment

manager = ExperimentManager(f"../runs/ensemble/optimization/multinomial", ["Fit", "Not Fit"])

# %%
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,StackingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from interpret.glassbox import ExplainableBoostingClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


def compute_cosine_similarity(X):
    """
    Compute cosine similarity between resume_text and job_description_text
    for each row in a DataFrame or compatible input.
    Returns a 2D NumPy array of shape (n_samples, 1).
    """

    # Defensive: ensure X is a DataFrame with expected columns
    if isinstance(X, np.ndarray):
        # If it's already an ndarray, we must know column order
        X = pd.DataFrame(X, columns=["resume_text", "job_description_text"])
    elif not isinstance(X, pd.DataFrame):
        raise ValueError("Input X must be a DataFrame or 2D ndarray.")

    if "resume_text" not in X.columns or "job_description_text" not in X.columns:
        raise ValueError("Expected columns 'resume_text' and 'job_description_text' not found.")

    # Flatten all text for vectorizer fit
    all_texts = X["resume_text"].astype(str).tolist() + X["job_description_text"].astype(str).tolist()
    
    # Fit vectorizer
    vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
    vectorizer.fit(all_texts)

    # Compute cosine similarity for each row
    cosine_scores = []
    for idx, row in X.iterrows():
        resume_text = str(row['resume_text'])
        job_text = str(row['job_description_text'])

        tfidf_matrix = vectorizer.transform([resume_text, job_text])
        cos_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
        cosine_scores.append(cos_sim)

    return np.array(cosine_scores).reshape(-1, 1)

def pipeline_factory(params):

    clf_lr = LogisticRegression(random_state=SEED)
    clf_rf = RandomForestClassifier(random_state=SEED)
    clf_nb = MultinomialNB()

    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ExplainableBoostingClassifier(random_state=SEED),
        cv=5,
        n_jobs=1
    )

    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', TfidfVectorizer()),
                ('selector', SelectKBest(chi2, k=100))
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])


experiment = Experiment(
    name=f"Baseline optimization EBM chi2 stack",
    description=f"No hyperparameter tuning yet but parameters are changed from defaults",
    pipeline_factory=pipeline_factory
)

manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: Baseline optimization EBM chi2 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6855
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6845
#    Micro F1:     0.6855
#    Weighted F1:  0.6845
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6880  R: 0.6855
#    Micro    - P: 0.6855  R: 0.6855
#    Weighted - P: 0.6880  R: 0.6855
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6663     0.7433     0.7027        857
#    Not Fit              0.7098     0.6278     0.6663        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6880     0.6855     0.6845       1714
#    weighted avg         0.6880     0.6855     0.6845       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           637      220
#    Not Fit       319      538
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'Baseline optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# # Experiment 2: Hyperparameter Optimization

# %% [markdown]
# ## Conservative Parameter Space

# %%
def conservative_ensemble_param_space(trial):
    """
    More conservative parameter space with fewer options
    Good for faster optimization with reasonable performance
    Updated with proper MultinomialNB parameters
    """
    params = {}
    
    # TF-IDF - Limited options
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        5000, 10000, 15000
    ])
    params['tfidf__sublinear_tf'] = trial.suggest_categorical('tfidf__sublinear_tf', [
        True, False
    ])
    
    # Feature Selection
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        100, 500, 1000, 2000
    ])
    
    # Logistic Regression - Simple
    params['clf__estimators__lr__C'] = trial.suggest_float('clf__estimators__lr__C', 
                                                          0.1, 10.0, log=True)
    params['clf__estimators__lr__class_weight'] = trial.suggest_categorical('clf__estimators__lr__class_weight', [
        None, 'balanced'
    ])
    
    # Random Forest - Simple
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical('clf__estimators__rf__n_estimators', [
        100, 200
    ])
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical('clf__estimators__rf__max_depth', [
        None, 10, 20
    ])
    
    # Multinomial Naive Bayes - Simple
    params['clf__estimators__nb__alpha'] = trial.suggest_float('clf__estimators__nb__alpha', 
                                                              0.1, 5.0, log=True)
    params['clf__estimators__nb__fit_prior'] = trial.suggest_categorical('clf__estimators__nb__fit_prior', [
        True, False
    ])
    
    # EBM - Simple
    params['clf__final_estimator__learning_rate'] = trial.suggest_float('clf__final_estimator__learning_rate', 
                                                                        0.01, 0.05)
    params['clf__final_estimator__interactions'] = trial.suggest_categorical('clf__final_estimator__interactions', [
        0, 3
    ])
    
    # Fixed parameters
    params['clf__estimators__lr__random_state'] = 42
    params['clf__estimators__rf__random_state'] = 42
    params['clf__final_estimator__random_state'] = 42
    params['clf__final_estimator__n_jobs'] = 1
    params['clf__estimators__rf__n_jobs'] = 1
    params['clf__n_jobs'] = 1
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = MultinomialNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"L1 Regularization optimization EBM chi2 stack",
    description=f"L1 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=conservative_ensemble_param_space 
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: L1 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-16 02:22:33,287] A new study created in memory with name: no-name-dd4feaea-9d3b-49c8-a431-b01ff5c94499
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:41<20:05, 41.56s/trial, Train: 0.9580 | Val: 0.7086 | B[I 2025-07-16 02:23:14,852] Trial 0 finished with value: 0.7086021505376344 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 5000, 'tfidf__sublinear_tf': True, 'selector__k': 500, 'clf__estimators__lr__C': 3.3582287076226405, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': None, 'clf__estimators__nb__alpha': 0.1813661200263177, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.04560130987670088, 'clf__final_estimator__interactions': 0}. Best is trial 0 with value: 0.7086021505376344.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [01:03<14:01, 30.07s/trial, Train: 0.7844 | Val: 0.6962 | B[I 2025-07-16 02:23:36,878] Trial 1 finished with value: 0.696236559139785 and parameters: {'tfidf__ngram_range': (1, 1), 'tfidf__max_features': 15000, 'tfidf__sublinear_tf': False, 'selector__k': 500, 'clf__estimators__lr__C': 0.16391827599477032, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__nb__alpha': 0.9123868864262411, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.03968903076968188, 'clf__final_estimator__interactions': 0}. Best is trial 0 with value: 0.7086021505376344.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:32<13:18, 29.56s/trial, Train: 0.8178 | Val: 0.7188 | B[I 2025-07-16 02:24:05,830] Trial 2 finished with value: 0.7188172043010753 and parameters: {'tfidf__ngram_range': (1, 1), 'tfidf__max_features': 5000, 'tfidf__sublinear_tf': False, 'selector__k': 500, 'clf__estimators__lr__C': 4.855800934048679, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__nb__alpha': 0.45879629524719445, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.023567731970986293, 'clf__final_estimator__interactions': 0}. Best is trial 2 with value: 0.7188172043010753.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [01:57<11:59, 27.69s/trial, Train: 0.7394 | Val: 0.6613 | B[I 2025-07-16 02:24:30,654] Trial 3 finished with value: 0.6612903225806451 and parameters: {'tfidf__ngram_range': (1, 1), 'tfidf__max_features': 15000, 'tfidf__sublinear_tf': True, 'selector__k': 100, 'clf__estimators__lr__C': 2.825503488357371, 'clf__estimators__lr__class_weight': None, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': None, 'clf__estimators__nb__alpha': 0.3059290307393215, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.04337262616368698, 'clf__final_estimator__interactions': 0}. Best is trial 2 with value: 0.7188172043010753.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  17%|▏| 5/30 [03:19<19:40, 47.20s/trial, Train: 0.9875 | Val: 0.7328 | B[I 2025-07-16 02:25:52,450] Trial 4 finished with value: 0.7327956989247312 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 15000, 'tfidf__sublinear_tf': False, 'selector__k': 2000, 'clf__estimators__lr__C': 0.4938754565252626, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': None, 'clf__estimators__nb__alpha': 1.528027419074305, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.025371909441101737, 'clf__final_estimator__interactions': 3}. Best is trial 4 with value: 0.7327956989247312.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  20%|▏| 6/30 [04:32<22:27, 56.13s/trial, Train: 0.9287 | Val: 0.7392 | B[I 2025-07-16 02:27:05,925] Trial 5 finished with value: 0.739247311827957 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 5000, 'tfidf__sublinear_tf': True, 'selector__k': 2000, 'clf__estimators__lr__C': 9.441381630298702, 'clf__estimators__lr__class_weight': None, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 20, 'clf__estimators__nb__alpha': 1.00825115665274, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.01995527282355239, 'clf__final_estimator__interactions': 0}. Best is trial 5 with value: 0.739247311827957.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fc2166a9da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f4eb468dda0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fc0e328dda0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f7254391da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f27565adda0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7ff23bfa1da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f5b98b95da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f6cde595da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f8b48c91da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f7d04895da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fde0dda1da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Hyperparameter Optimization (Custom Val Split):  23%|▏| 7/30 [05:08<18:57, 49.47s/trial, Train: 0.8971 | Val: 0.6952 | B[I 2025-07-16 02:27:41,667] Trial 6 finished with value: 0.6951612903225807 and parameters: {'tfidf__ngram_range': (1, 1), 'tfidf__max_features': 15000, 'tfidf__sublinear_tf': False, 'selector__k': 100, 'clf__estimators__lr__C': 1.8516175900940182, 'clf__estimators__lr__class_weight': None, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 20, 'clf__estimators__nb__alpha': 2.2391965507113, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.019850639896403833, 'clf__final_estimator__interactions': 3}. Best is trial 5 with value: 0.739247311827957.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  27%|▎| 8/30 [05:38<15:52, 43.28s/trial, Train: 0.7366 | Val: 0.6742 | B[I 2025-07-16 02:28:11,712] Trial 7 finished with value: 0.6741935483870968 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 10000, 'tfidf__sublinear_tf': False, 'selector__k': 100, 'clf__estimators__lr__C': 1.9306996786137272, 'clf__estimators__lr__class_weight': None, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__nb__alpha': 0.19485028760804243, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.015132251080390048, 'clf__final_estimator__interactions': 0}. Best is trial 5 with value: 0.739247311827957.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  30%|▎| 9/30 [06:12<14:09, 40.46s/trial, Train: 0.9696 | Val: 0.7301 | B[I 2025-07-16 02:28:45,970] Trial 8 finished with value: 0.7301075268817204 and parameters: {'tfidf__ngram_range': (1, 1), 'tfidf__max_features': 5000, 'tfidf__sublinear_tf': False, 'selector__k': 500, 'clf__estimators__lr__C': 2.3098989182929466, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth

# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  97%|▉| 29/30 [30:14<01:04, 64.56s/trial, Train: 0.7133 | Val: 0.6769 | [I 2025-07-16 02:52:47,406] Trial 28 finished with value: 0.6768817204301075 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 10000, 'tfidf__sublinear_tf': True, 'selector__k': 100, 'clf__estimators__lr__C': 6.039408262273764, 'clf__estimators__lr__class_weight': None, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__nb__alpha': 1.9390030171772052, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.022539175920287223, 'clf__final_estimator__interactions': 3}. Best is trial 10 with value: 0.7483870967741936.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [30:58<00:00, 58.45s/trial, Train: 0.9061 | Val: 0.7054 | [I 2025-07-16 02:53:31,585] Trial 29 finished with value: 0.7053763440860215 and parameters: {'tfidf__ngram_range': (1, 2), 'tfidf__max_features': 15000, 'tfidf__sublinear_tf': True, 'selector__k': 1000, 'clf__estimators__lr__C': 3.5481259802601577, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': None, 'clf__estimators__nb__alpha': 0.5040904641971109, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.029882621201063178, 'clf__final_estimator__interactions': 3}. Best is trial 10 with value: 0.7483870967741936.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [30:58<00:00, 61.94s/trial, Train: 0.9061 | Val: 0.7054 |
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7484
#    Total trials: 30
# 🔧 Training final model with best parameters...
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6744
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6738
#    Micro F1:     0.6744
#    Weighted F1:  0.6738
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6758  R: 0.6744
#    Micro    - P: 0.6744  R: 0.6744
#    Weighted - P: 0.6758  R: 0.6744
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6909     0.6313     0.6598        857
#    Not Fit              0.6606     0.7176     0.6879        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6758     0.6744     0.6738       1714
#    weighted avg         0.6758     0.6744     0.6738       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           541      316
#    Not Fit       242      615
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'L1 Regularization optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# ## L1 Regularization Space

# %%
def l1_regularization_param_space(trial):
    """
    Parameter space focused on L1 regularization (Lasso)
    Uses liblinear/saga solvers that support L1
    Updated with proper MultinomialNB parameters
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: L1 PENALTY ONLY ==========
    params['clf__estimators__lr__penalty'] = 'l1'  # Fixed to L1
    params['clf__estimators__lr__solver'] = trial.suggest_categorical(
        'clf__estimators__lr__solver', ['liblinear', 'saga']
    )
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__max_iter'] = 1000
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== MULTINOMIAL NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.1, 10.0, log=True
    )
    params['clf__estimators__nb__fit_prior'] = trial.suggest_categorical(
        'clf__estimators__nb__fit_prior', [True, False]
    )
    # class_prior is typically left as None to learn from data
    # force_alpha parameter for handling zero probabilities
    params['clf__estimators__nb__force_alpha'] = trial.suggest_categorical(
        'clf__estimators__nb__force_alpha', [True, False]
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = MultinomialNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"L1 Regularization optimization EBM chi2 stack",
    description=f"L1 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=l1_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: L1 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-16 02:54:24,818] A new study created in memory with name: no-name-680c42c3-1310-4033-b2b1-c259c5695335
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:39<19:13, 39.78s/trial, Train: 0.7004 | Val: 0.6742 | B[I 2025-07-16 02:55:04,596] Trial 0 finished with value: 0.6741935483870968 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.85, 'selector__k': 500, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.35372493610517736, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 0.4677356556014939, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.0011602571065400674, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 0 with value: 0.6741935483870968.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [01:06<14:54, 31.94s/trial, Train: 0.7009 | Val: 0.6608 | B[I 2025-07-16 02:55:31,052] Trial 1 finished with value: 0.660752688172043 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.8, 'selector__k': 200, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.0035395231894270224, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 6.971929427099864, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.009529232202720325, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 0 with value: 0.6741935483870968.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:40<14:45, 32.80s/trial, Train: 0.7193 | Val: 0.6747 | B[I 2025-07-16 02:56:04,875] Trial 2 finished with value: 0.6747311827956989 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 10, 'tfidf__max_df': 0.8, 'selector__k': 300, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.15807826069526806, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.22257467682454452, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.0011668839002672495, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 2 with value: 0.6747311827956989.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [02:01<12:19, 28.43s/trial, Train: 0.7101 | Val: 0.6866 | B[I 2025-07-16 02:56:26,596] Trial 3 finished with value: 0.6865591397849462 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.85, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.0023106999962488276, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.33602374555261594, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.005125454958929843, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 3 with value: 0.6865591397849462.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  17%|▏| 5/30 [02:26<11:19, 27.16s/trial, Train: 0.7080 | Val: 0.6747 | B[I 2025-07-16 02:56:51,526] Trial 4 finished with value: 0.6747311827956989 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.7, 'selector__k': 200, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.10025287368436023, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 2.1168607547160465, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.00433733568395128, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 3 with value: 0.6865591397849462.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  20%|▏| 6/30 [02:56<11:11, 28.00s/trial, Train: 0.7119 | Val: 0.6661 | B[I 2025-07-16 02:57:21,136] Trial 5 finished with value: 0.6661290322580645 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.8, 'selector__k': 100, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.0065005183599218825, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.5230552414989951, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.002479828938515781, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 32, 'clf__cv': 5}. Best is trial 3 with value: 0.6865591397849462.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  23%|▏| 7/30 [03:21<10:23, 27.10s/trial, Train: 0.7154 | Val: 0.6796 | B[I 2025-07-16 02:57:46,397] Trial 6 finished with value: 0.6795698924731183 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.85, 'selector__k': 50, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.0011987200144215361, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 0.46629102444674425, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.0031299500748312964, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__cv': 5}. Best is trial 3 with value: 0.6865591397849462.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  27%|▎| 8/30 [03:42<09:12, 25.09s/trial, Train: 0.6970 | Val: 0.6769 | B[I 2025-07-16 02:58:07,182] Trial 7 finished with value: 0.6768817204301075 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.8, 'selector__k': 100, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.03666994336985357, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 1.1508652806239552, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.011482692464275355, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__cv': 5}. Best is trial 3 with value: 0.6865591397849462.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):
and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.8, 'selector__k': 300, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.5096467833757828, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.10176053338827797, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.004303226489998396, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__cv': 10}. Best is trial 18 with value: 0.7301075268817204.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [16:31<00:00, 35.41s/trial, Train: 0.6940 | Val: 0.6726 | [I 2025-07-16 03:10:55,970] Trial 29 finished with value: 0.6725806451612903 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.7, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.27085691131494877, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 0.19899135415632618, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.0071533247697759565, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__cv': 5}. Best is trial 18 with value: 0.7301075268817204.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [16:31<00:00, 33.04s/trial, Train: 0.6940 | Val: 0.6726 |
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7301
#    Total trials: 30
# 🔧 Training final model with best parameters...
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6867
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6856
#    Micro F1:     0.6867
#    Weighted F1:  0.6856
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6894  R: 0.6867
#    Micro    - P: 0.6867  R: 0.6867
#    Weighted - P: 0.6894  R: 0.6867
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6667     0.7468     0.7045        857
#    Not Fit              0.7122     0.6266     0.6667        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6894     0.6867     0.6856       1714
#    weighted avg         0.6894     0.6867     0.6856       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           640      217
#    Not Fit       320      537
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'L1 Regularization optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# ## L2 Parameter Space

# %%
def l2_regularization_param_space(trial):
    """
    Parameter space focused on L2 regularization (Ridge)
    Uses lbfgs/saga solvers that work well with L2
    Updated with proper MultinomialNB parameters
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: L2 PENALTY ONLY ==========
    params['clf__estimators__lr__penalty'] = 'l2'  # Fixed to L2
    params['clf__estimators__lr__solver'] = trial.suggest_categorical(
        'clf__estimators__lr__solver', ['lbfgs', 'saga']
    )
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__max_iter'] = 1000
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== MULTINOMIAL NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.1, 10.0, log=True
    )
    params['clf__estimators__nb__fit_prior'] = trial.suggest_categorical(
        'clf__estimators__nb__fit_prior', [True, False]
    )
    # class_prior is typically left as None to learn from data
    # force_alpha parameter for handling zero probabilities
    params['clf__estimators__nb__force_alpha'] = trial.suggest_categorical(
        'clf__estimators__nb__force_alpha', [True, False]
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = MultinomialNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        passthrough=True,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"L2 Regularization optimization EBM chi2 stack",
    description=f"L2 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=l2_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: L2 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-16 03:11:30,424] A new study created in memory with name: no-name-2abe57f3-ab3c-46e4-a6d5-92d7788a3722
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [01:05<31:45, 65.72s/trial, Train: 0.7286 | Val: 0.6839 | B[I 2025-07-16 03:12:36,145] Trial 0 finished with value: 0.6838709677419355 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.8, 'selector__k': 200, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.007586638997371254, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 0.3625454806484498, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.0010306724195251343, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__cv': 10}. Best is trial 0 with value: 0.6838709677419355.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [08:43<2:18:21, 296.49s/trial, Train: 0.7728 | Val: 0.7005 [I 2025-07-16 03:20:14,173] Trial 1 finished with value: 0.7005376344086022 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.8, 'selector__k': 500, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.02472085248806232, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 2.985180516646479, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.0022575514327166863, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins':
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6538     0.7141     0.6827        857
#    Not Fit              0.6851     0.6219     0.6520        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6695     0.6680     0.6673       1714
#    weighted avg         0.6695     0.6680     0.6673       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           612      245
#    Not Fit       324      533
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'L2 Regularization optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# ## Elasticnet Parameter Space

# %%
def elasticnet_regularization_param_space(trial):
    """
    Parameter space focused on ElasticNet regularization
    Uses saga solver (only one that supports elasticnet)
    Updated with proper MultinomialNB parameters
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: ELASTICNET PENALTY ==========
    params['clf__estimators__lr__penalty'] = 'elasticnet'  # Fixed to elasticnet
    params['clf__estimators__lr__solver'] = 'saga'  # Only solver that supports elasticnet
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__l1_ratio'] = trial.suggest_float(
        'clf__estimators__lr__l1_ratio', 0.1, 0.9
    )
    params['clf__estimators__lr__max_iter'] = 2000  # ElasticNet may need more iterations
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== MULTINOMIAL NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.1, 10.0, log=True
    )
    params['clf__estimators__nb__fit_prior'] = trial.suggest_categorical(
        'clf__estimators__nb__fit_prior', [True, False]
    )
    # class_prior is typically left as None to learn from data
    # force_alpha parameter for handling zero probabilities
    params['clf__estimators__nb__force_alpha'] = trial.suggest_categorical(
        'clf__estimators__nb__force_alpha', [True, False]
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = MultinomialNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"ElasticNet Regularization optimization EBM chi2 stack",
    description=f"ElasticNet focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=elasticnet_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: ElasticNet Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-16 04:29:35,048] A new study created in memory with name: no-name-611e9c5f-fb1d-489f-a7c0-1eb9bf56d631
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:22<10:56, 22.65s/trial, Train: 0.7066 | Val: 0.6699 | B[I 2025-07-16 04:29:57,701] Trial 0 finished with value: 0.6698924731182796 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__C': 0.006309383527266579, 'clf__estimators__lr__l1_ratio': 0.3627443373646766, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 5.326266514341449, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.0012162570637559828, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__cv': 5}. Best is trial 0 with value: 0.6698924731182796.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [00:57<13:53, 29.78s/trial, Train: 0.7777 | Val: 0.6892 | B[I 2025-07-16 04:30:32,467] Trial 1 finished with value: 0.689247311827957 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 3, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__C': 0.057530539402068946, 'clf__estimators__lr__l1_ratio': 0.4801801729392735, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.2562816446089899, 'clf__estimators__nb__fit_prior': True, 'clf__estimators__nb__force_alpha': True, 'clf__final_estimator__learning_rate': 0.005001488051476799, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 1 with value: 0.689247311827957.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:18<11:36, 25.81s/trial, Train: 0.6810 | Val: 0.6597 | B[I 2025-07-16 04:30:53,561] Trial 2 finished with value: 0.6596774193548387 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__C': 0.0017899814846723432, 'clf__estimators__lr__l1_ratio': 0.7041933666001751, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 9.372442438396257, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.0027615851306236477, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 1 with value: 0.689247311827957.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [01:40<10:30, 24.26s/trial, Train: 0.6884 | Val: 0.6538 | B[I 2025-07-16 04:31:15,444] Trial 3 finished with value: 0.6537634408602151 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__C': 0.0011779869922706426, 'clf__estimators__lr__l1_ratio': 0.789251475365205, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha':
 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 1.6662995455717777, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.010733481757227992, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 7}. Best is trial 15 with value: 0.7172043010752688.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  93%|▉| 28/30 [18:20<01:28, 44.08s/trial, Train: 0.8017 | Val: 0.7124 | [I 2025-07-16 04:47:55,572] Trial 27 finished with value: 0.7123655913978495 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'selector__k': 500, 'clf__estimators__lr__C': 0.40652250120949485, 'clf__estimators__lr__l1_ratio': 0.12437582741488878, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 1.6756130460744332, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.01052740430068223, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 7}. Best is trial 15 with value: 0.7172043010752688.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  97%|▉| 29/30 [18:57<00:41, 41.98s/trial, Train: 0.7592 | Val: 0.6973 | [I 2025-07-16 04:48:32,647] Trial 28 finished with value: 0.6973118279569892 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.7, 'selector__k': 500, 'clf__estimators__lr__C': 0.3422850761993516, 'clf__estimators__lr__l1_ratio': 0.22843636163630224, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 1.678411137089823, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.012256105459128887, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 15 with value: 0.7172043010752688.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [19:23<00:00, 37.13s/trial, Train: 0.7013 | Val: 0.6790 | [I 2025-07-16 04:48:58,489] Trial 29 finished with value: 0.6790322580645162 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'selector__k': 100, 'clf__estimators__lr__C': 0.6929581325387099, 'clf__estimators__lr__l1_ratio': 0.17747360384804256, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 5.538674403695886, 'clf__estimators__nb__fit_prior': False, 'clf__estimators__nb__force_alpha': False, 'clf__final_estimator__learning_rate': 0.0010331882930373797, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__cv': 7}. Best is trial 15 with value: 0.7172043010752688.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [19:23<00:00, 38.78s/trial, Train: 0.7013 | Val: 0.6790 |
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7172
#    Total trials: 30
# 🔧 Training final model with best parameters...
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6692
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6691
#    Micro F1:     0.6692
#    Weighted F1:  0.6691
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6693  R: 0.6692
#    Micro    - P: 0.6692  R: 0.6692
#    Weighted - P: 0.6693  R: 0.6692
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6651     0.6814     0.6732        857
#    Not Fit              0.6734     0.6569     0.6651        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6693     0.6692     0.6691       1714
#    weighted avg         0.6693     0.6692     0.6691       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           584      273
#    Not Fit       294      563
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ElasticNet Regularization optimization EBM chi2 stack' completed and logged.

# %%
manager.compare_experiments()

dir = "../experiment_summaries/ensemble_optimization"
filename  = "ensemble_optimization_summaries.csv"

manager.export_experiment_summary(dir, filename)
# Out:
# === Experiment Comparison (accuracy) ===
# Experiment                     Test Score   Status
# -------------------------------------------------------
# Baseline optimization EBM chi2 stack 0.6855       ✅ Completed
# L1 Regularization optimization EBM chi2 stack 0.6744       ✅ Completed
# L1 Regularization optimization EBM chi2 stack 0.6867       ✅ Completed
# L2 Regularization optimization EBM chi2 stack 0.6680       ✅ Completed
# ElasticNet Regularization optimization EBM chi2 stack 0.6692       ✅ Completed
# 📊 Experiment summary exported to: ensemble_optimization_summaries.csv
#                                                 name     status  \
# 0               Baseline optimization EBM chi2 stack  Completed
# 1      L1 Regularization optimization EBM chi2 stack  Completed
# 2      L1 Regularization optimization EBM chi2 stack  Completed
# 3      L2 Regularization optimization EBM chi2 stack  Completed
# 4  ElasticNet Regularization optimization EBM chi...  Completed
#
#                     timestamp  \
# 0  2025-07-16T02:22:33.214350
# 1  2025-07-16T02:54:24.744163
# 2  2025-07-16T03:11:30.387340
# 3  2025-07-16T04:29:34.834919
# 4  2025-07-16T04:49:40.700575
#
#                                          description  test_accuracy  \
# 0  No hyperparameter tuning yet but parameters ar...       0.685531
# 1                   L1 focused hyperparameter tuning       0.674446
# 2                   L1 focused hyperparameter tuning       0.686698
# 3                   L2 focused hyperparameter tuning       0.668028
# 4           ElasticNet focused hyperparameter tuning       0.669195
#
#    test_macro_precision  test_macro_recall  test_macro_f1  \
# 0              0.688040           0.685531       0.684478
# 1              0.675756           0.674446       0.673838
# 2              0.689434           0.686698       0.685562
# 3              0.669468           0.668028       0.667321
# 4              0.669297           0.669195       0.669145
#
#    test_micro_precision  test_micro_recall  test_micro_f1  \
# 0              0.685531           0.685531       0.685531
# 1              0.674446           0.674446       0.674446
# 2              0.686698           0.686698       0.686698
# 3              0.668028           0.668028       0.668028
# 4              0.669195           0.669195       0.669195
#
#    test_weighted_precision  test_weighted_recall  test_weighted_f1  \
# 0                 0.688040              0.685531          0.684478
# 1                 0.675756              0.674446          0.673838
# 2                 0.689434              0.686698          0.685562
# 3                 0.669468              0.668028          0.667321
# 4                 0.669297              0.669195          0.669145
#
#    test_num_samples  test_num_classes
# 0              1714                 2
# 1              1714                 2
# 2              1714                 2
# 3              1714                 2
# 4              1714                 2

# %% [markdown]
# ### Comprehensive L2

# %%
def fixed_comprehensive_l2_space(trial):
    """
    Fixed comprehensive L2 regularization parameter space.
    
    Fixes:
    - Missing bootstrap parameter
    - Invalid parameter combinations  
    - Reduces excessive parameter space
    - Removes non-existent parameters
    """
    params = {}
    
    # ========== TF-IDF: COMPREHENSIVE BUT VALID ==========
    
    # Vocabulary size - reasonable range
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000, 7500  # Reduced from 9 to 5 options
    ])
    
    # N-gram ranges - valid combinations
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2), (1, 3)  # Removed problematic (2,2) and (2,3)
    ])
    
    # Document frequency - focused range
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        2, 3, 5, 10, 0.01, 0.02  # Reduced from 13 to 6 options
    ])
    
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85, 0.9  # Reduced from 8 to 4 options
    ])
    
    # Advanced TF-IDF settings
    params['tfidf__sublinear_tf'] = trial.suggest_categorical('tfidf__sublinear_tf', [
        True, False
    ])
    
    params['tfidf__use_idf'] = trial.suggest_categorical('tfidf__use_idf', [
        True, False
    ])
    
    params['tfidf__stop_words'] = trial.suggest_categorical('tfidf__stop_words', [
        'english', None
    ])
    
    params['tfidf__norm'] = trial.suggest_categorical('tfidf__norm', [
        'l1', 'l2'  # Removed None to ensure normalization
    ])
    
    params['tfidf__binary'] = trial.suggest_categorical('tfidf__binary', [
        True, False
    ])
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500, 750  # Reduced from 12 to 6 options
    ])
    
    # ========== LOGISTIC REGRESSION: FIXED L2 ==========
    
    params['clf__estimators__lr__penalty'] = 'l2'
    
    # Solvers - removed problematic 'sag' 
    params['clf__estimators__lr__solver'] = trial.suggest_categorical(
        'clf__estimators__lr__solver', [
            'lbfgs', 'saga', 'newton-cg'  # Removed 'sag' for stability
        ]
    )
    
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 1e-4, 10.0, log=True  # Reduced range
    )
    
    params['clf__estimators__lr__max_iter'] = trial.suggest_categorical(
        'clf__estimators__lr__max_iter', [1000, 2000]  # Reduced options
    )
    
    params['clf__estimators__lr__class_weight'] = trial.suggest_categorical(
        'clf__estimators__lr__class_weight', ['balanced', None]
    )
    
    params['clf__estimators__lr__tol'] = trial.suggest_float(
        'clf__estimators__lr__tol', 1e-5, 1e-3, log=True
    )
    
    # ========== RANDOM FOREST: FIXED BOOTSTRAP ISSUES ==========
    
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [100, 150, 200]  # Reduced options
    )
    
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [5, 10, 15, None]  # Reduced options
    )
    
    # Fixed criterion - removed 'log_loss'
    params['clf__estimators__rf__criterion'] = trial.suggest_categorical(
        'clf__estimators__rf__criterion', ['gini', 'entropy']
    )
    
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2', None]
    )
    
    # FIXED: Bootstrap parameter (was missing!)
    bootstrap_enabled = trial.suggest_categorical(
        'clf__estimators__rf__bootstrap', [True, False]
    )
    params['clf__estimators__rf__bootstrap'] = bootstrap_enabled
    
    # max_samples only valid when bootstrap=True
    if bootstrap_enabled:
        params['clf__estimators__rf__max_samples'] = trial.suggest_categorical(
            'clf__estimators__rf__max_samples', [None, 0.8, 0.9]
        )
    else:
        params['clf__estimators__rf__max_samples'] = None
    
    params['clf__estimators__rf__class_weight'] = trial.suggest_categorical(
        'clf__estimators__rf__class_weight', ['balanced', None]  # Removed 'balanced_subsample'
    )
    
    # OOB disabled as requested
    params['clf__estimators__rf__oob_score'] = False
    
    # ========== NAIVE BAYES: FIXED PARAMETERS ==========
    
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.1, 10.0, log=True  # Reduced range
    )
    
    params['clf__estimators__nb__fit_prior'] = trial.suggest_categorical(
        'clf__estimators__nb__fit_prior', [True, False]
    )
    
    # REMOVED: force_alpha doesn't exist in sklearn
    
    # ========== EBM: REASONABLE PARAMETERS ==========
    
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.05, log=True
    )
    
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [1000, 2000, 3000]  # Reduced options
    )
    
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [50, 100, 150]
    )
    
    params['clf__final_estimator__validation_size'] = trial.suggest_float(
        'clf__final_estimator__validation_size', 0.15, 0.25
    )
    
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]  # Reduced from 5 options
    )
    
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [64, 128, 256]  # Reduced options
    )
    
    # EBM regularization
    params['clf__final_estimator__outer_bags'] = trial.suggest_categorical(
        'clf__final_estimator__outer_bags', [8, 12, 16]
    )
    
    params['clf__final_estimator__inner_bags'] = trial.suggest_categorical(
        'clf__final_estimator__inner_bags', [0, 4]
    )
    
    params['clf__final_estimator__smoothing_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__smoothing_rounds', [0, 100]
    )
    
    params['clf__final_estimator__max_leaves'] = trial.suggest_categorical(
        'clf__final_estimator__max_leaves', [3, 4]
    )
    
    # ========== STACKING: REASONABLE CV ==========
    
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [
        10, 15  # Reduced from 4 to 2 options (20 is too high)
    ])
    
    # Fixed stacking method
    params['clf__stack_method'] = trial.suggest_categorical('clf__stack_method', [
        'auto', 'predict_proba'  # Most stable options
    ])
    
    return params


def validate_parameter_space():
    """
    Test function to validate the parameter space works.
    """
    import optuna
    
    # Create a test trial
    study = optuna.create_study()
    trial = study.ask()
    
    try:
        params = fixed_comprehensive_l2_space(trial)
        print("✅ Parameter space is valid!")
        print(f"Sample parameters generated: {len(params)} total")
        
        # Check for required RF parameters
        required_rf_params = [
            'clf__estimators__rf__bootstrap',
            'clf__estimators__rf__max_samples',
            'clf__estimators__rf__oob_score'
        ]
        
        for param in required_rf_params:
            if param in params:
                print(f"✅ {param}: {params[param]}")
            else:
                print(f"❌ Missing: {param}")
                
        return True
        
    except Exception as e:
        print(f"❌ Parameter space invalid: {e}")
        return False

# Usage:
"""
# Test the fixed version:
validate_parameter_space()

# Use in your experiment:
experiment = Experiment(
    name="Fixed Comprehensive L2 Regularization",
    description="Corrected parameter space without conflicts",
    pipeline_factory=pipeline_factory,
    param_space=fixed_comprehensive_l2_space
)
"""
# Out:
# '\n# Test the fixed version:\nvalidate_parameter_space()\n\n# Use in your experiment:\nexperiment = Experiment(\n    name="Fixed Comprehensive L2 Regularization",\n    description="Corrected parameter space without conflicts",\n    pipeline_factory=pipeline_factory,\n    param_space=fixed_comprehensive_l2_space\n)\n'

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = MultinomialNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        passthrough=True,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 80,        # Increase from 5 to 20 for better optimization
    "cv_folds": 15,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"Comprehensive L2 Regularization optimization EBM chi2 stack",
    description=f"Wider L2 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=fixed_comprehensive_l2_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: Comprehensive L2 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/80 [00:00<?, ?trial/s][I 2025-07-16 09:00:06,398] A new study created in memory with name: no-name-ccfc2615-c5a3-496e-af9e-0f0b80edba8a
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   1%| | 1/80 [01:18<1:43:58, 78.97s/trial, Train: 0.7648 | Val: 0.7027 |[I 2025-07-16 09:01:25,374] Trial 0 finished with value: 0.7026881720430107 and parameters: {'tfidf__max_features': 7500, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.7, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': True, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': True, 'selector__k': 200, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 0.02500304524716945, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__lr__tol': 0.00039979222371292714, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': None, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 2.0864744807202915, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.010015945597103742, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.2031008155081835, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 12, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 0 with value: 0.7026881720430107.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   2%| | 2/80 [05:37<4:00:07, 184.71s/trial, Train: 0.8268 | Val: 0.6849 [I 2025-07-16 09:05:44,102] Trial 1 finished with value: 0.6849462365591398 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': True, 'selector__k': 50, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 1.6795689347073177, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__lr__tol': 3.3761618557633924e-05, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': None, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 2.7854281199229747, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.001206979954506566, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.15514824480896622, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 12, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 15, 'clf__stack_method': 'auto'}. Best is trial 0 with value: 0.7026881720430107.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   4%| | 3/80 [06:32<2:40:48, 125.30s/trial, Train: 0.7276 | Val: 0.6973 [I 2025-07-16 09:06:38,714] Trial 2 finished with value: 0.6973118279569892 and parameters: {'tfidf__max_features': 7500, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': True, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': True, 'selector__k': 50, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 2.5272698869053083, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 2.049913403568775e-05, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': None, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.9, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 3.3132145076270496, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.015055794322794979, 'clf__final_estimator__max_rounds': 3000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.2069647013436257, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 0 with value: 0.7026881720430107.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   5%| | 4/80 [13:06<4:53:02, 231.35s/trial, Train: 0.7731 | Val: 0.6989 [I 2025-07-16 09:13:12,633] Trial 3 finished with value: 0.6989247311827957 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 3, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': True, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': True, 'selector__k': 100, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.00022883402792879073, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 2.258484801197612e-05, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 0.3461805687801703, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.010444022876206119, 'clf__final_estimator__max_rounds': 3000, 'clf__final_estimator__early_stopping_rounds': 150, 'clf__final_estimator__validation_size': 0.16189719680227346, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 12, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 15, 'clf__stack_method': 'predict_proba'}. Best is trial 0 with value: 0.7026881720430107.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   6%| | 5/80 [14:21<3:38:48, 175.04s/trial, Train: 0.7583 | Val: 0.6876 [I 2025-07-16 09:14:27,837] Trial 4 finished with value: 0.6876344086021505 and parameters: {'tfidf__max_features': 7500, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l2', 'tfidf__binary': False, 'selector__k': 100, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 1.17657475201274, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__lr__tol': 1.697013581124308e-05, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 1.587834792267253, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.003616649152788197, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 150, 'clf__final_estimator__validation_size': 0.17282859859180275, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 15, 'clf__stack_method': 'auto'}. Best is trial 0 with value: 0.7026881720430107.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   8%| | 6/80 [18:38<4:10:21, 203.00s/trial, Train: 0.8508 | Val: 0.7086 [I 2025-07-16 09:18:45,104] Trial 5 finished with value: 0.7086021505376344 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 3, 'tfidf__max_df': 0.8, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': True, 'tfidf__stop_words': None, 'tfidf__norm': 'l2', 'tfidf__binary': True, 'selector__k': 300, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 0.041967481480397494, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 2.4972346248532596e-05, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 1.3625340084798576, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.0010203826519870937, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.19597021370114748, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 5 with value: 0.7086021505376344.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   9%| | 7/80 [29:36<7:07:42, 351.54s/trial, Train: 0.8337 | Val: 0.6925 [I 2025-07-16 09:29:42,471] Trial 6 finished with value: 0.6924731182795699 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': True, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': True, 'selector__k': 300, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 0.013238954113065655, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 9.537035329689562e-05, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': None, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 0.12318700209978858, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.010676315859601772, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.18977287575037458, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 5 with value: 0.7086021505376344.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 8/80 [37:58<7:59:25, 399.53s/trial, Train: 0.7714 | Val: 0.6957 [I 2025-07-16 09:38:04,740] Trial 7 finished with value: 0.6956989247311828 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': True, 'tfidf__stop_words': None, 'tfidf__norm': 'l2', 'tfidf__binary': True, 'selector__k': 500, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 0.28201507492802086, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': 'balanced', 'clf__estimators__lr__tol': 0.00016855435475739142, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 0.6917797791858153, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.0011822129061696504, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.17156938005122407, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 12, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 5 with value: 0.7086021505376344.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  11%| | 9/80 [46:54<8:43:20, 442.25s/trial, Train: 0.8014 | Val: 0.7118 [I 2025-07-16 09:47:00,945] Trial 8 finished with value: 0.7118279569892473 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 3, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 300, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 1.5861592472111044, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0008030461824042377, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': None, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 0.3586590443704549, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.0016943425173724844, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.19803002328938207, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__final_estimator__outer_bags': 12, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 8 with value: 0.7118279569892473.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  12%|▏| 10/80 [49:52<7:00:41, 360.59s/trial, Train: 0.8171 | Val: 0.7027[I 2025-07-16 09:49:58,667] Trial 9 finished with value: 0.7026881720430107 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.8, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l2', 'tfidf__binary': True, 'selector__k': 200, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.0005841486966856971, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0004383755366894407, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': None, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 0.3623340570411949, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.0022046525624027933, 'clf__final_estimator__max_rounds': 3000, 'clf__final_estimator__early_stopping_rounds': 150, 'clf__final_estimator__validation_size': 0.17100959811296773, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 15, 'clf__stack_method': 'predict_proba'}. Best is trial 8 with value: 0.7118279569892473.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  14%|▏| 11/80 [59:01<8:01:09, 418.40s/trial, Train: 0.8044 | Val: 0.7140[I 2025-07-16 09:59:08,149] Trial 10 finished with value: 0.7139784946236559 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 8.629870407621917, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0009605605741432986, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 0.10079557051300304, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.033072079068951474, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.2414874296108258, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 10 with value: 0.7139784946236559.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  15%|▏| 12/80 [1:08:07<8:38:03, 457.11s/trial, Train: 0.8169 | Val: 0.71[I 2025-07-16 10:08:13,805] Trial 11 finished with value: 0.7134408602150538 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 9.407293341970629, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.000968115123875562, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 9.253017445061724, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.04897438673039233, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.24572347465679106, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 10 with value: 0.7139784946236559.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  16%|▏| 13/80 [1:17:14<9:00:49, 484.32s/trial, Train: 0.8107 | Val: 0.71[I 2025-07-16 10:17:20,718] Trial 12 finished with value: 0.714516129032258 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 6.905559445998234, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0009500506865922139, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 9.69763962669567, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.04815771880847056, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.2493873413323018, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 12 with value: 0.714516129032258.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  18%|▏| 14/80 [1:26:21<9:13:34, 503.25s/trial, Train: 0.8125 | Val: 0.72[I 2025-07-16 10:26:27,719] Trial 13 finished with value: 0.7204301075268817 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 8.826008202544918, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0003105938916088225, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 0.10316382996330298, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.04676884852279755, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.24770674777303467, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 13 with value: 0.7204301075268817.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  19%|▏| 15/80 [1:35:34<9:21:32, 518.34s/trial, Train: 0.8054 | Val: 0.71[I 2025-07-16 10:35:41,036] Trial 14 finished with value: 0.7161290322580646 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.2406167136179635, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.00025272490239430984, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 5.062501524947568, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.022137108913214673, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.22839147778220042, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 13 with value: 0.7204301075268817.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  20%|▏| 16/80 [1:37:57<7:12:19, 405.30s/trial, Train: 0.8289 | Val: 0.71[I 2025-07-16 10:38:03,823] Trial 15 finished with value: 0.7139784946236559 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.19399035473225867, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.00015566831976157022, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 5.144012766497731, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.025204611301621525, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.22641019732253104, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 13 with value: 0.7204301075268817.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  21%|▏| 17/80 [1:47:08<7:51:40, 449.21s/trial, Train: 0.8000 | Val: 0.71[I 2025-07-16 10:47:15,159] Trial 16 finished with value: 0.7139784946236559 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.0018527261251580628, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 6.24768029971575e-05, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 0.6314208672527475, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.02254168052911117, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.22855935200347693, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 13 with value: 0.7204301075268817.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  22%|▏| 18/80 [1:52:33<7:05:30, 411.78s/trial, Train: 0.8118 | Val: 0.71[I 2025-07-16 10:52:39,800] Trial 17 finished with value: 0.7150537634408602 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 2, 'tfidf__max_df': 0.9, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': 'english', 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.22199819026604203, 'clf__estimators__lr__max_iter': 2000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.00026245586839402084, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__criterion': 'gini', 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__rf__bootstrap': False, 'clf__estimators__rf__class_weight': 'balanced', 'clf__estimators__nb__alpha': 0.18343380285814098, 'clf__estimators__nb__fit_prior': True, 'clf__final_estimator__learning_rate': 0.01861767985508276, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__validation_size': 0.2263470913488135, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 256, 'clf__final_estimator__outer_bags': 8, 'clf__final_estimator__inner_bags': 4, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'predict_proba'}. Best is trial 13 with value: 0.7204301075268817.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# ...
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  95%|▉| 76/80 [20:21:57<2:57:36, 2664.02s/trial, Train: 0.9493 | Val: 0.[I 2025-07-17 05:22:03,775] Trial 75 finished with value: 0.7387096774193549 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 1.8765346720630574, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0005763910783250136, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 4.4830922234653, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.002366339104984213, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.16947316248003452, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 3, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 58 with value: 0.7419354838709677.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  96%|▉| 77/80 [21:09:21<2:15:54, 2718.03s/trial, Train: 0.9500 | Val: 0.[I 2025-07-17 06:09:27,833] Trial 76 finished with value: 0.7397849462365591 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 4.291244206944811, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0005917000043873391, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 2.7111615551382657, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.00453626983123899, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.17762931902030815, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 58 with value: 0.7419354838709677.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  98%|▉| 78/80 [21:36:32<1:19:43, 2391.98s/trial, Train: 0.8695 | Val: 0.[I 2025-07-17 06:36:39,024] Trial 77 finished with value: 0.7064516129032258 and parameters: {'tfidf__max_features': 7500, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l2', 'tfidf__binary': True, 'selector__k': 750, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 4.729924647617383, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.00042890622761208755, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 2.561298676410553, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.005851269132335844, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.17811287147883303, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 100, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 58 with value: 0.7419354838709677.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  99%|▉| 79/80 [22:05:22<36:33, 2193.41s/trial, Train: 0.9250 | Val: 0.71[I 2025-07-17 07:05:29,096] Trial 78 finished with value: 0.7166666666666667 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.8, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 500, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 0.15628359344303672, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0006010115003490669, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': 0.8, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 2.0981882887634575, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.0030976911031332936, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.16552377527404735, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 58 with value: 0.7419354838709677.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 3) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split): 100%|█| 80/80 [22:56:27<00:00, 2454.80s/trial, Train: 0.9576 | Val: 0.73[I 2025-07-17 07:56:33,827] Trial 79 finished with value: 0.7370967741935484 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 3), 'tfidf__min_df': 2, 'tfidf__max_df': 0.85, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False, 'tfidf__stop_words': None, 'tfidf__norm': 'l1', 'tfidf__binary': False, 'selector__k': 750, 'clf__estimators__lr__solver': 'newton-cg', 'clf__estimators__lr__C': 6.077712836398984, 'clf__estimators__lr__max_iter': 1000, 'clf__estimators__lr__class_weight': None, 'clf__estimators__lr__tol': 0.0006720358223572177, 'clf__estimators__rf__n_estimators': 200, 'clf__estimators__rf__max_depth': 15, 'clf__estimators__rf__criterion': 'entropy', 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': None, 'clf__estimators__rf__bootstrap': True, 'clf__estimators__rf__max_samples': None, 'clf__estimators__rf__class_weight': None, 'clf__estimators__nb__alpha': 1.5407423191297478, 'clf__estimators__nb__fit_prior': False, 'clf__final_estimator__learning_rate': 0.00731852156882048, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__validation_size': 0.15066562281939125, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__final_estimator__outer_bags': 16, 'clf__final_estimator__inner_bags': 0, 'clf__final_estimator__smoothing_rounds': 0, 'clf__final_estimator__max_leaves': 4, 'clf__cv': 10, 'clf__stack_method': 'auto'}. Best is trial 58 with value: 0.7419354838709677.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 80/80 [22:56:27<00:00, 1032.34s/trial, Train: 0.9576 | Val: 0.73
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7419
#    Total trials: 80
# 🔧 Training final model with best parameters...
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6844
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6843
#    Micro F1:     0.6844
#    Weighted F1:  0.6843
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6846  R: 0.6844
#    Micro    - P: 0.6844  R: 0.6844
#    Weighted - P: 0.6846  R: 0.6844
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6783     0.7013     0.6896        857
#    Not Fit              0.6908     0.6674     0.6789        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6846     0.6844     0.6843       1714
#    weighted avg         0.6846     0.6844     0.6843       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           601      256
#    Not Fit       285      572
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'Comprehensive L2 Regularization optimization EBM chi2 stack' completed and logged.
