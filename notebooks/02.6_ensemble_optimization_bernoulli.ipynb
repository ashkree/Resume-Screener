# %%
import sys
sys.path.append('..')

# %%
import warnings
import multiprocessing
warnings.filterwarnings("ignore", category=ResourceWarning)

# Also suppress multiprocessing warnings
import sys
import os
os.environ['PYTHONWARNINGS'] = 'ignore::ResourceWarning'

# %% [markdown]
# # Data Loading

# %%
from pathlib import Path
import pandas as pd

def load_datasets(data_root: str | Path = "data",
                  tasks: tuple[str, ...] = ("binary", "multiclass"),
                  splits: tuple[str, ...] = ("train", "val", "test")) -> dict:

    data_root = Path(data_root)
    datasets  = {}

    for task in tasks:
        task_dir     = data_root / task
        task_dict    = {}

        for split in splits:
            split_dict = {}
            for kind in ("X", "y"):
                file_path = task_dir / f"{kind}_{split}.pkl"
                split_dict[kind] = pd.read_pickle(file_path)
            task_dict[split] = split_dict

        datasets[task] = task_dict

    return datasets

# %%
from typing import Tuple, Literal
import pandas as pd

def load_split(
    preprocessing_type: Literal["cleaned_only", "full_process"],
    sampling_method: Literal["undersampled", "oversampled"],
    classification_type: Literal["binary", "multiclass"]
) -> Tuple[
    Tuple[pd.DataFrame, pd.Series],  # train: (X_train, y_train)
    Tuple[pd.DataFrame, pd.Series],  # val: (X_val, y_val)
    Tuple[pd.DataFrame, pd.Series]   # test: (X_test, y_test)
]:
    """
    Load different types of splits from the data
    
    Args:
        preprocessing_type: must be "cleaned_only" or "full_process"
        sampling_method: must be "undersampled" or "oversampled"
        classification_type: must be "binary" or "multiclass"
    
    Returns:
        Tuple of (train, val, test) splits, where each split is (X, y)
        - train: (X_train, y_train)
        - val: (X_val, y_val)  
        - test: (X_test, y_test)
    """
    dataset = load_datasets(
        f"../data/{preprocessing_type}/{sampling_method}")[classification_type]
    split_names = ["train", "val", "test"]

    return tuple([(lambda split: (dataset[split]["X"], dataset[split]["y"]))(split) for split in split_names])

# %% [markdown]
# # Experiments

# %%
def combine_text(X):
    X = X.copy()

    combined = X["resume_text"].astype(
        str) + " [SEP] " + X["job_description_text"].astype(str)

    return combined.values

# %%
splits = load_split(preprocessing_type="cleaned_only", sampling_method="undersampled", classification_type="binary")

# %%
SEED = 42

# %% [markdown]
# # Experiment 1: Base Parameters

# %%
from utils import ExperimentManager, Experiment

manager = ExperimentManager(f"../runs/ensemble/optimization/bernoulli/", ["Fit", "Not Fit"])

# %%
from sklearn.feature_selection import chi2, SelectKBest
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,StackingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from interpret.glassbox import ExplainableBoostingClassifier
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


def compute_cosine_similarity(X):
    """
    Compute cosine similarity between resume_text and job_description_text
    for each row in a DataFrame or compatible input.
    Returns a 2D NumPy array of shape (n_samples, 1).
    """

    # Defensive: ensure X is a DataFrame with expected columns
    if isinstance(X, np.ndarray):
        # If it's already an ndarray, we must know column order
        X = pd.DataFrame(X, columns=["resume_text", "job_description_text"])
    elif not isinstance(X, pd.DataFrame):
        raise ValueError("Input X must be a DataFrame or 2D ndarray.")

    if "resume_text" not in X.columns or "job_description_text" not in X.columns:
        raise ValueError("Expected columns 'resume_text' and 'job_description_text' not found.")

    # Flatten all text for vectorizer fit
    all_texts = X["resume_text"].astype(str).tolist() + X["job_description_text"].astype(str).tolist()
    
    # Fit vectorizer
    vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
    vectorizer.fit(all_texts)

    # Compute cosine similarity for each row
    cosine_scores = []
    for idx, row in X.iterrows():
        resume_text = str(row['resume_text'])
        job_text = str(row['job_description_text'])

        tfidf_matrix = vectorizer.transform([resume_text, job_text])
        cos_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
        cosine_scores.append(cos_sim)

    return np.array(cosine_scores).reshape(-1, 1)

def pipeline_factory(params):

    clf_lr = LogisticRegression(random_state=SEED)
    clf_rf = RandomForestClassifier(random_state=SEED)
    clf_nb = BernoulliNB()

    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ExplainableBoostingClassifier(random_state=SEED),
        cv=5,
        n_jobs=1
    )

    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', TfidfVectorizer()),
                ('selector', SelectKBest(chi2, k=100))
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])


experiment = Experiment(
    name=f"Baseline optimization EBM chi2 stack",
    description=f"No hyperparameter tuning yet but parameters are changed from defaults",
    pipeline_factory=pipeline_factory
)

manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: Baseline optimization EBM chi2 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6814
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6801
#    Micro F1:     0.6814
#    Weighted F1:  0.6801
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6845  R: 0.6814
#    Micro    - P: 0.6814  R: 0.6814
#    Weighted - P: 0.6845  R: 0.6814
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6608     0.7456     0.7007        857
#    Not Fit              0.7082     0.6173     0.6596        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6845     0.6814     0.6801       1714
#    weighted avg         0.6845     0.6814     0.6801       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           639      218
#    Not Fit       328      529
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'Baseline optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# # Experiment 2: Hyperparameter Optimization

# %% [markdown]
# ## Conservative Parameter Space

# %%
def conservative_ensemble_param_space(trial):
    """
    More conservative parameter space with fewer options
    Good for faster optimization with reasonable performance
    """
    params = {}
    
    # TF-IDF - Limited options
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        5000, 10000, 15000
    ])
    params['tfidf__sublinear_tf'] = trial.suggest_categorical('tfidf__sublinear_tf', [
        True, False
    ])
    
    # Feature Selection
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        100, 500, 1000, 2000
    ])
    
    # Logistic Regression - Simple
    params['clf__estimators__lr__C'] = trial.suggest_float('clf__estimators__lr__C', 
                                                          0.1, 10.0, log=True)
    params['clf__estimators__lr__class_weight'] = trial.suggest_categorical('clf__estimators__lr__class_weight', [
        None, 'balanced'
    ])
    
    # Random Forest - Simple
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical('clf__estimators__rf__n_estimators', [
        100, 200
    ])
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical('clf__estimators__rf__max_depth', [
        None, 10, 20
    ])
    
    # Naive Bayes - Simple
    params['clf__estimators__nb__alpha'] = trial.suggest_float('clf__estimators__nb__alpha', 
                                                              0.5, 2.0)
    
    # EBM - Simple
    params['clf__final_estimator__learning_rate'] = trial.suggest_float('clf__final_estimator__learning_rate', 
                                                                        0.01, 0.05)
    params['clf__final_estimator__interactions'] = trial.suggest_categorical('clf__final_estimator__interactions', [
        0, 3
    ])
    
    # Fixed parameters
    params['clf__estimators__lr__random_state'] = 42
    params['clf__estimators__rf__random_state'] = 42
    params['clf__final_estimator__random_state'] = 42
    params['clf__final_estimator__n_jobs'] = 1
    params['clf__estimators__rf__n_jobs'] = 1
    params['clf__n_jobs'] = 1
    
    return params

# %% [markdown]
# ## L1 Regularization Space

# %%
def l1_regularization_param_space(trial):
    """
    Parameter space focused on L1 regularization (Lasso)
    Uses liblinear/saga solvers that support L1
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: L1 PENALTY ONLY ==========
    params['clf__estimators__lr__penalty'] = 'l1'  # Fixed to L1
    params['clf__estimators__lr__solver'] = trial.suggest_categorical(
        'clf__estimators__lr__solver', ['liblinear', 'saga']
    )
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__max_iter'] = 1000
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.5, 5.0
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = BernoulliNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"L1 Regularization optimization EBM chi2 stack",
    description=f"L1 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=l1_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: L1 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-15 23:20:05,668] A new study created in memory with name: no-name-6609a21d-2ba6-4d7f-bf5f-2223068da0fb
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:24<11:36, 24.02s/trial, Train: 0.6986 | Val: 0.6763 | B[I 2025-07-15 23:20:29,694] Trial 0 finished with value: 0.6763440860215054 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.85, 'selector__k': 100, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.013648799370370042, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 3.582439613132824, 'clf__final_estimator__learning_rate': 0.003641374501882251, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 0 with value: 0.6763440860215054.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [00:57<13:40, 29.30s/trial, Train: 0.6965 | Val: 0.6602 | B[I 2025-07-15 23:21:02,692] Trial 1 finished with value: 0.6602150537634408 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.8, 'selector__k': 50, 'clf__estimators__lr__solver': 'liblinear', 'clf__estimators__lr__C': 0.43943083808152233, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 4.883153233550998, 'clf__final_estimator__learning_rate': 0.005912699145845607, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 7}. Best is trial 0 with value: 0.6763440860215054.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:25<12:55, 28.72s/trial, Train: 0.7470 | Val: 0.6774 | B[I 2025-07-15 23:21:30,727] Trial 2 finished with value: 0.6774193548387096 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.009201610540218664, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 4.9312640908066285, 'clf__final_estimator__learning_rate': 0.0042650258510173, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 2 with value: 0.6774193548387096.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [01:50<11:52, 27.42s/trial, Train: 0.6972 | Val: 0.6570 | B[I 2025-07-15 23:21:56,149] Trial 3 finished with value: 0.656989247311828 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.85, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.001164903374510742, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 2.281188063307022, 'clf__final_estimator__learning_rate': 0.009793059823791875, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins':
 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 2.0250080091028804, 'clf__final_estimator__learning_rate': 0.004774522578760478, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 10 with value: 0.7161290322580646.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [16:24<00:00, 32.83s/trial, Train: 0.7025 | Val: 0.6780 |
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7161
#    Total trials: 30
# 🔧 Training final model with best parameters...
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6663
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6661
#    Micro F1:     0.6663
#    Weighted F1:  0.6661
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6666  R: 0.6663
#    Micro    - P: 0.6663  R: 0.6663
#    Weighted - P: 0.6666  R: 0.6663
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6596     0.6873     0.6731        857
#    Not Fit              0.6736     0.6453     0.6591        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6666     0.6663     0.6661       1714
#    weighted avg         0.6666     0.6663     0.6661       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           589      268
#    Not Fit       304      553
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'L1 Regularization optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# ## L2 Parameter Space

# %%
def l2_regularization_param_space(trial):
    """
    Parameter space focused on L2 regularization (Ridge)
    Uses lbfgs/saga solvers that work well with L2
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: L2 PENALTY ONLY ==========
    params['clf__estimators__lr__penalty'] = 'l2'  # Fixed to L2
    params['clf__estimators__lr__solver'] = trial.suggest_categorical(
        'clf__estimators__lr__solver', ['lbfgs', 'saga']
    )
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__max_iter'] = 1000
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.5, 5.0
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = BernoulliNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        passthrough=True,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"L2 Regularization optimization EBM chi2 stack",
    description=f"L2 focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=l2_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: L2 Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-15 23:36:59,018] A new study created in memory with name: no-name-d38b7507-9d5d-4e5b-a2fc-d6f4fc46447f
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:37<18:07, 37.49s/trial, Train: 0.7030 | Val: 0.6801 | B[I 2025-07-15 23:37:36,508] Trial 0 finished with value: 0.6801075268817204 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.85, 'selector__k': 50, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.006500772939840752, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 4.555199971262057, 'clf__final_estimator__learning_rate': 0.004320008388957367, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 32, 'clf__cv': 5}. Best is trial 0 with value: 0.6801075268817204.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [01:16<17:46, 38.11s/trial, Train: 0.7375 | Val: 0.6876 | B[I 2025-07-15 23:38:15,049] Trial 1 finished with value: 0.6876344086021505 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.12324821816703102, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 3.1414850909346073, 'clf__final_estimator__learning_rate': 0.012283861244758476, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 1 with value: 0.6876344086021505.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:56<17:43, 39.40s/trial, Train: 0.7364 | Val: 0.6780 | B[I 2025-07-15 23:38:55,987] Trial 2 finished with value: 0.6779569892473118 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'selector__k': 50, 'clf__estimators__lr__solver': 'lbfgs', 'clf__estimators__lr__C': 0.7070599993871859, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 4.211806213139638, 'clf__final_estimator__learning_rate': 0.01899430533412167, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 32, 'clf__cv': 5}. Best is trial 1 with value: 0.6876344086021505.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [10:30<1:38:12, 226.63s/trial, Train: 0.7917 | Val: 0.7081 [I 2025-07-15 23:47:29,646] Trial 3 finished with value: 0.7080645161290322 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.8, 'selector__k': 500, 'clf__estimators__lr__solver': 'saga', 'clf__estimators__lr__C': 0.002497909543218617, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 3.2900842685927176, 'clf__final_estimator__learning_rate': 0.0025896657338550255, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 3 with value: 0.7080645161290322.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6832  R: 0.6803
#    Micro    - P: 0.6803  R: 0.6803
#    Weighted - P: 0.6832  R: 0.6803
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6601     0.7433     0.6992        857
#    Not Fit              0.7063     0.6173     0.6588        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6832     0.6803     0.6790       1714
#    weighted avg         0.6832     0.6803     0.6790       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           637      220
#    Not Fit       328      529
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'L2 Regularization optimization EBM chi2 stack' completed and logged.

# %% [markdown]
# ## Elasticnet Parameter Space

# %%
def elasticnet_regularization_param_space(trial):
    """
    Parameter space focused on ElasticNet regularization
    Uses saga solver (only one that supports elasticnet)
    """
    params = {}
    
    # ========== TF-IDF: AGGRESSIVE REGULARIZATION ==========
    params['tfidf__max_features'] = trial.suggest_categorical('tfidf__max_features', [
        1000, 2000, 3000, 5000
    ])
    params['tfidf__ngram_range'] = trial.suggest_categorical('tfidf__ngram_range', [
        (1, 1), (1, 2)
    ])
    params['tfidf__min_df'] = trial.suggest_categorical('tfidf__min_df', [
        3, 5, 10, 0.01, 0.02
    ])
    params['tfidf__max_df'] = trial.suggest_categorical('tfidf__max_df', [
        0.7, 0.8, 0.85
    ])
    params['tfidf__sublinear_tf'] = True
    params['tfidf__use_idf'] = True
    params['tfidf__stop_words'] = 'english'
    
    # ========== FEATURE SELECTION ==========
    params['selector__k'] = trial.suggest_categorical('selector__k', [
        50, 100, 200, 300, 500
    ])
    
    # ========== LOGISTIC REGRESSION: ELASTICNET PENALTY ==========
    params['clf__estimators__lr__penalty'] = 'elasticnet'  # Fixed to elasticnet
    params['clf__estimators__lr__solver'] = 'saga'  # Only solver that supports elasticnet
    params['clf__estimators__lr__C'] = trial.suggest_float(
        'clf__estimators__lr__C', 0.001, 1.0, log=True
    )
    params['clf__estimators__lr__l1_ratio'] = trial.suggest_float(
        'clf__estimators__lr__l1_ratio', 0.1, 0.9
    )
    params['clf__estimators__lr__max_iter'] = 2000  # ElasticNet may need more iterations
    params['clf__estimators__lr__class_weight'] = 'balanced'
    
    # ========== RANDOM FOREST: PREVENT OVERFITTING ==========
    params['clf__estimators__rf__n_estimators'] = trial.suggest_categorical(
        'clf__estimators__rf__n_estimators', [50, 100, 150]
    )
    params['clf__estimators__rf__max_depth'] = trial.suggest_categorical(
        'clf__estimators__rf__max_depth', [3, 5, 7, 10]
    )
    params['clf__estimators__rf__min_samples_split'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_split', [10, 20, 50]
    )
    params['clf__estimators__rf__min_samples_leaf'] = trial.suggest_categorical(
        'clf__estimators__rf__min_samples_leaf', [5, 10, 20]
    )
    params['clf__estimators__rf__max_features'] = trial.suggest_categorical(
        'clf__estimators__rf__max_features', ['sqrt', 'log2']
    )
    params['clf__estimators__rf__class_weight'] = 'balanced'
    params['clf__estimators__rf__bootstrap'] = True
    
    # ========== NAIVE BAYES ==========
    params['clf__estimators__nb__alpha'] = trial.suggest_float(
        'clf__estimators__nb__alpha', 0.5, 5.0
    )
    
    # ========== EBM: CONSERVATIVE SETTINGS ==========
    params['clf__final_estimator__learning_rate'] = trial.suggest_float(
        'clf__final_estimator__learning_rate', 0.001, 0.02, log=True
    )
    params['clf__final_estimator__max_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__max_rounds', [500, 1000, 2000]
    )
    params['clf__final_estimator__early_stopping_rounds'] = trial.suggest_categorical(
        'clf__final_estimator__early_stopping_rounds', [25, 50, 100]
    )
    params['clf__final_estimator__validation_size'] = 0.2
    params['clf__final_estimator__interactions'] = trial.suggest_categorical(
        'clf__final_estimator__interactions', [0, 1, 2]
    )
    params['clf__final_estimator__max_bins'] = trial.suggest_categorical(
        'clf__final_estimator__max_bins', [32, 64, 128]
    )
    
    # ========== STACKING ==========
    params['clf__cv'] = trial.suggest_categorical('clf__cv', [5, 7, 10])
    
    return params

# %%
def pipeline_factory(params):
    """
    Properly handle nested parameters for ensemble pipeline
    """
    
    # ========== EXTRACT PARAMETERS FOR EACH COMPONENT ==========
    
    # TF-IDF parameters
    tfidf_params = {}
    for key, value in params.items():
        if key.startswith('tfidf__'):
            param_name = key.replace('tfidf__', '')
            tfidf_params[param_name] = value
    
    # Feature selector parameters
    selector_params = {}
    for key, value in params.items():
        if key.startswith('selector__'):
            param_name = key.replace('selector__', '')
            selector_params[param_name] = value
    
    # LogisticRegression parameters
    lr_params = {'random_state': SEED}
    for key, value in params.items():
        if key.startswith('clf__estimators__lr__'):
            param_name = key.replace('clf__estimators__lr__', '')
            lr_params[param_name] = value
    
    # RandomForest parameters
    rf_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__estimators__rf__'):
            param_name = key.replace('clf__estimators__rf__', '')
            rf_params[param_name] = value
    
    # NaiveBayes parameters
    nb_params = {}
    for key, value in params.items():
        if key.startswith('clf__estimators__nb__'):
            param_name = key.replace('clf__estimators__nb__', '')
            nb_params[param_name] = value
    
    # EBM parameters
    ebm_params = {'random_state': SEED, 'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__final_estimator__'):
            param_name = key.replace('clf__final_estimator__', '')
            ebm_params[param_name] = value
    
    # Stacking parameters
    stacking_params = {'n_jobs': 1}
    for key, value in params.items():
        if key.startswith('clf__') and '__' not in key.replace('clf__', ''):
            param_name = key.replace('clf__', '')
            stacking_params[param_name] = value
    
    # ========== CREATE COMPONENTS WITH PARAMETERS ==========
    
    # Create TF-IDF vectorizer
    tfidf = TfidfVectorizer(**tfidf_params)
    
    # Create feature selector
    if not selector_params:
        selector_params['k'] = 100  # Default value
    selector = SelectKBest(chi2, **selector_params)
    
    # Create base estimators
    try:
        clf_lr = LogisticRegression(**lr_params)
    except ValueError as e:
        print(f"LogReg parameter error: {e}")
        # Fallback to safe parameters
        clf_lr = LogisticRegression(random_state=SEED, C=1.0, penalty='l2', solver='lbfgs')
    
    clf_rf = RandomForestClassifier(**rf_params)
    clf_nb = BernoulliNB(**nb_params)
    
    # Create EBM meta-learner
    try:
        ebm = ExplainableBoostingClassifier(**ebm_params)
    except Exception as e:
        print(f"EBM parameter error: {e}")
        # Fallback to safe parameters
        ebm = ExplainableBoostingClassifier(random_state=SEED, n_jobs=1)
    
    # Create stacking classifier
    stacking_clf = StackingClassifier(
        estimators=[
            ('lr', clf_lr),
            ('nb', clf_nb),
            ('rf', clf_rf)
        ],
        final_estimator=ebm,
        **stacking_params
    )
    
    return Pipeline([
        ('features', FeatureUnion([
            # TF-IDF features
            ('tfidf_features', Pipeline([
                ("join", FunctionTransformer(combine_text, validate=False)),
                ('tfidf', tfidf),
                ('selector', selector)
            ])),
            
            # Cosine similarity feature with scaling
            ('cosine_sim', Pipeline([
                ('extract', FunctionTransformer(compute_cosine_similarity, validate=False))
            ]))
        ])),
        ('clf', stacking_clf)
    ])

optuna_kwargs = {
    "n_trials": 30,        # Increase from 5 to 20 for better optimization
    "cv_folds": 20,         # Reduce from 10 to 5 for faster training
    "scoring": "accuracy",
    "random_state": SEED,
    "optimise":True
}

experiment = Experiment(
    name=f"ElasticNet Regularization optimization EBM chi2 stack",
    description=f"ElasticNet focused hyperparameter tuning",
    pipeline_factory=pipeline_factory,
    param_space=elasticnet_regularization_param_space
)

manager.run_experiment(experiment, splits=splits, **optuna_kwargs)
# Out:
# === Running Experiment: ElasticNet Regularization optimization EBM chi2 stack ===
# Hyperparameter Optimization (Custom Val Split):   0%|                                         | 0/30 [00:00<?, ?trial/s][I 2025-07-16 01:41:10,575] A new study created in memory with name: no-name-89991111-256c-48b4-a637-4b9f1dea3e71
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   3%| | 1/30 [00:23<11:34, 23.93s/trial, Train: 0.7184 | Val: 0.6860 | B[I 2025-07-16 01:41:34,509] Trial 0 finished with value: 0.6860215053763441 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.7, 'selector__k': 300, 'clf__estimators__lr__C': 0.38097714291113866, 'clf__estimators__lr__l1_ratio': 0.7531359880622237, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.5149401937924916, 'clf__final_estimator__learning_rate': 0.011671875351247803, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 0 with value: 0.6860215053763441.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):   7%| | 2/30 [00:49<11:40, 25.03s/trial, Train: 0.6970 | Val: 0.6914 | B[I 2025-07-16 01:42:00,303] Trial 1 finished with value: 0.6913978494623656 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.8, 'selector__k': 300, 'clf__estimators__lr__C': 0.52012107303458, 'clf__estimators__lr__l1_ratio': 0.6970949354133267, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 4.78458694503912, 'clf__final_estimator__learning_rate': 0.0036074739953076175, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 5}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  10%| | 3/30 [01:12<10:47, 23.97s/trial, Train: 0.6877 | Val: 0.6645 | B[I 2025-07-16 01:42:23,022] Trial 2 finished with value: 0.6645161290322581 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.85, 'selector__k': 200, 'clf__estimators__lr__C': 0.007886769834168809, 'clf__estimators__lr__l1_ratio': 0.8079397767296034, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 1.9282516260084086, 'clf__final_estimator__learning_rate': 0.010197204724104375, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  13%|▏| 4/30 [01:45<11:52, 27.40s/trial, Train: 0.7488 | Val: 0.6710 | B[I 2025-07-16 01:42:55,681] Trial 3 finished with value: 0.6709677419354839 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 10, 'tfidf__max_df': 0.85, 'selector__k': 100, 'clf__estimators__lr__C': 0.08499674461660554, 'clf__estimators__lr__l1_ratio': 0.47058023330277077, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 4.00435885722649, 'clf__final_estimator__learning_rate': 0.0018881382160467156, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 50, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 128, 'clf__cv': 10}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  17%|▏| 5/30 [02:12<11:26, 27.45s/trial, Train: 0.7166 | Val: 0.6855 | B[I 2025-07-16 01:43:23,224] Trial 4 finished with value: 0.6854838709677419 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 10, 'tfidf__max_df': 0.8, 'selector__k': 50, 'clf__estimators__lr__C': 0.004816190827032937, 'clf__estimators__lr__l1_ratio': 0.4592446739333418, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 2.765386508152371, 'clf__final_estimator__learning_rate': 0.007968248089165728, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  20%|▏| 6/30 [02:39<10:56, 27.37s/trial, Train: 0.7202 | Val: 0.6656 | B[I 2025-07-16 01:43:50,436] Trial 5 finished with value: 0.6655913978494624 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.7, 'selector__k': 50, 'clf__estimators__lr__C': 0.4381578810640721, 'clf__estimators__lr__l1_ratio': 0.5054536028658442, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 3.800913058533721, 'clf__final_estimator__learning_rate': 0.016154670437371132, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  23%|▏| 7/30 [03:09<10:48, 28.19s/trial, Train: 0.6963 | Val: 0.6758 | B[I 2025-07-16 01:44:20,311] Trial 6 finished with value: 0.6758064516129032 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 5, 'tfidf__max_df': 0.85, 'selector__k': 300, 'clf__estimators__lr__C': 0.13903438034142565, 'clf__estimators__lr__l1_ratio': 0.13294412183605842, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 10, 'clf__estimators__rf__min_samples_leaf': 20, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 3.591484935102141, 'clf__final_estimator__learning_rate': 0.0032094355415372773, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 1, 'clf__final_estimator__max_bins': 64, 'clf__cv': 5}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  27%|▎| 8/30 [03:35<10:04, 27.48s/trial, Train: 0.6960 | Val: 0.6726 | B[I 2025-07-16 01:44:46,284] Trial 7 finished with value: 0.6725806451612903 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.7, 'selector__k': 200, 'clf__estimators__lr__C': 0.04124573530702318, 'clf__estimators__lr__l1_ratio': 0.7226021322364482, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 4.240643842785293, 'clf__final_estimator__learning_rate': 0.01893106327927344, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 128, 'clf__cv': 7}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  30%|▎| 9/30 [03:57<08:57, 25.61s/trial, Train: 0.7357 | Val: 0.6812 | B[I 2025-07-16 01:45:07,759] Trial 8 finished with value: 0.6811827956989247 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.7, 'selector__k': 100, 'clf__estimators__lr__C': 0.029848405754411854, 'clf__estimators__lr__l1_ratio': 0.8552837246403298, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 10, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'log2', 'clf__estimators__nb__alpha': 4.923309603249675, 'clf__final_estimator__learning_rate': 0.009875488558072349, 'clf__final_estimator__max_rounds': 500, 'clf__final_estimator__early_stopping_rounds': 25, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 32, 'clf__cv': 5}. Best is trial 1 with value: 0.6913978494623656.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  33%|▎| 10/30 [04:17<07:59, 23.95s/trial, Train: 0.7373 | Val: 0.6925 | [I 2025-07-16 01:45:28,001] Trial 9 finished with value: 0.6924731182795699 and parameters: {'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.02, 'tfidf__max_df': 0.8, 'selector__k': 500, 'clf__estimators__lr__C': 0.0033848666648214564, 'clf__estimators__lr__l1_ratio': 0.5236215885704885, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth':
 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 1.6678680589283574, 'clf__final_estimator__learning_rate': 0.00249050794428644, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 15 with value: 0.7016129032258065.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  87%|▊| 26/30 [11:18<01:51, 27.94s/trial, Train: 0.7535 | Val: 0.6866 | [I 2025-07-16 01:52:28,875] Trial 25 finished with value: 0.6865591397849462 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.8, 'selector__k': 100, 'clf__estimators__lr__C': 0.0019350580500152213, 'clf__estimators__lr__l1_ratio': 0.199066331870478, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 1.0343232218788052, 'clf__final_estimator__learning_rate': 0.002497068288960236, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 15 with value: 0.7016129032258065.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  90%|▉| 27/30 [11:48<01:26, 28.69s/trial, Train: 0.7945 | Val: 0.6946 | [I 2025-07-16 01:52:59,301] Trial 26 finished with value: 0.6946236559139785 and parameters: {'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.8, 'selector__k': 500, 'clf__estimators__lr__C': 0.01689049457927506, 'clf__estimators__lr__l1_ratio': 0.3210169637990773, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.5745097036982376, 'clf__final_estimator__learning_rate': 0.001395997220626303, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 15 with value: 0.7016129032258065.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  93%|▉| 28/30 [12:11<00:53, 26.94s/trial, Train: 0.7620 | Val: 0.6919 | [I 2025-07-16 01:53:22,153] Trial 27 finished with value: 0.6919354838709677 and parameters: {'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 0.01, 'tfidf__max_df': 0.8, 'selector__k': 500, 'clf__estimators__lr__C': 0.0067642130209352586, 'clf__estimators__lr__l1_ratio': 0.4134635584826295, 'clf__estimators__rf__n_estimators': 50, 'clf__estimators__rf__max_depth': 7, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 1.8010879932396198, 'clf__final_estimator__learning_rate': 0.001731908596669815, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 15 with value: 0.7016129032258065.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split):  97%|▉| 29/30 [12:37<00:26, 26.62s/trial, Train: 0.6995 | Val: 0.6672 | [I 2025-07-16 01:53:48,045] Trial 28 finished with value: 0.6672043010752688 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 5, 'tfidf__max_df': 0.85, 'selector__k': 500, 'clf__estimators__lr__C': 0.0036918512787227045, 'clf__estimators__lr__l1_ratio': 0.6273567414407211, 'clf__estimators__rf__n_estimators': 150, 'clf__estimators__rf__max_depth': 3, 'clf__estimators__rf__min_samples_split': 20, 'clf__estimators__rf__min_samples_leaf': 10, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 3.2662439775641796, 'clf__final_estimator__learning_rate': 0.0010040849386885467, 'clf__final_estimator__max_rounds': 2000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 0, 'clf__final_estimator__max_bins': 32, 'clf__cv': 10}. Best is trial 15 with value: 0.7016129032258065.
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 1) which is of type tuple.
#   warnings.warn(message)
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (1, 2) which is of type tuple.
#   warnings.warn(message)
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [13:08<00:00, 27.84s/trial, Train: 0.7122 | Val: 0.6957 | [I 2025-07-16 01:54:18,741] Trial 29 finished with value: 0.6956989247311828 and parameters: {'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__min_df': 3, 'tfidf__max_df': 0.7, 'selector__k': 300, 'clf__estimators__lr__C': 0.8415072421047561, 'clf__estimators__lr__l1_ratio': 0.42690243465512256, 'clf__estimators__rf__n_estimators': 100, 'clf__estimators__rf__max_depth': 5, 'clf__estimators__rf__min_samples_split': 50, 'clf__estimators__rf__min_samples_leaf': 5, 'clf__estimators__rf__max_features': 'sqrt', 'clf__estimators__nb__alpha': 0.517654699948802, 'clf__final_estimator__learning_rate': 0.003194510339994012, 'clf__final_estimator__max_rounds': 1000, 'clf__final_estimator__early_stopping_rounds': 100, 'clf__final_estimator__interactions': 2, 'clf__final_estimator__max_bins': 64, 'clf__cv': 7}. Best is trial 15 with value: 0.7016129032258065.
# Hyperparameter Optimization (Custom Val Split): 100%|█| 30/30 [13:08<00:00, 26.27s/trial, Train: 0.7122 | Val: 0.6957 |
# 🎯 Optimization completed using Custom Val Split!
#    Best score: 0.7016
#    Total trials: 30
# 🔧 Training final model with best parameters...
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /home/maveron/.conda/envs/304/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# ✅ Training complete!
# 📊 Logging optimization summary...
# ✅ Optimization summary logged!
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6307
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6307
#    Micro F1:     0.6307
#    Weighted F1:  0.6307
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6307  R: 0.6307
#    Micro    - P: 0.6307  R: 0.6307
#    Weighted - P: 0.6307  R: 0.6307
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6330     0.6219     0.6274        857
#    Not Fit              0.6284     0.6394     0.6339        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6307     0.6307     0.6307       1714
#    weighted avg         0.6307     0.6307     0.6307       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           533      324
#    Not Fit       309      548
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ElasticNet Regularization optimization EBM chi2 stack' completed and logged.

# %%
manager.compare_experiments()

dir = "../experiment_summaries/ensemble_optimization"
filename  = "ensemble_optimization_summaries.csv"

manager.export_experiment_summary(dir, filename)
# Out:
# === Experiment Comparison (accuracy) ===
# Experiment                     Test Score   Status
# -------------------------------------------------------
# Baseline optimization EBM chi2 stack 0.6814       ✅ Completed
# L1 Regularization optimization EBM chi2 stack 0.6663       ✅ Completed
# L2 Regularization optimization EBM chi2 stack 0.6803       ✅ Completed
# ElasticNet Regularization optimization EBM chi2 stack 0.6307       ✅ Completed
# 📊 Experiment summary exported to: ensemble_optimization_summaries.csv
#                                                 name     status  \
# 0               Baseline optimization EBM chi2 stack  Completed
# 1      L1 Regularization optimization EBM chi2 stack  Completed
# 2      L2 Regularization optimization EBM chi2 stack  Completed
# 3  ElasticNet Regularization optimization EBM chi...  Completed
#
#                     timestamp  \
# 0  2025-07-15T23:20:05.591521
# 1  2025-07-15T23:36:58.982653
# 2  2025-07-16T01:41:10.517114
# 3  2025-07-16T01:54:39.248084
#
#                                          description  test_accuracy  \
# 0  No hyperparameter tuning yet but parameters ar...       0.681447
# 1                   L1 focused hyperparameter tuning       0.666278
# 2                   L2 focused hyperparameter tuning       0.680280
# 3           ElasticNet focused hyperparameter tuning       0.630688
#
#    test_macro_precision  test_macro_recall  test_macro_f1  \
# 0              0.684486           0.681447       0.680129
# 1              0.666572           0.666278       0.666130
# 2              0.683189           0.680280       0.679006
# 3              0.630728           0.630688       0.630660
#
#    test_micro_precision  test_micro_recall  test_micro_f1  \
# 0              0.681447           0.681447       0.681447
# 1              0.666278           0.666278       0.666278
# 2              0.680280           0.680280       0.680280
# 3              0.630688           0.630688       0.630688
#
#    test_weighted_precision  test_weighted_recall  test_weighted_f1  \
# 0                 0.684486              0.681447          0.680129
# 1                 0.666572              0.666278          0.666130
# 2                 0.683189              0.680280          0.679006
# 3                 0.630728              0.630688          0.630660
#
#    test_num_samples  test_num_classes
# 0              1714                 2
# 1              1714                 2
# 2              1714                 2
# 3              1714                 2
