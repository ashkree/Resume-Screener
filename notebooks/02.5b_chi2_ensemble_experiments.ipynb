# %%
import sys
sys.path.append('..')

# %%
import warnings
import multiprocessing
warnings.filterwarnings("ignore", category=ResourceWarning)

# Also suppress multiprocessing warnings
import sys
import os
os.environ['PYTHONWARNINGS'] = 'ignore::ResourceWarning'

# %% [markdown]
# # Data Loading

# %%
from pathlib import Path
import pandas as pd

def load_datasets(data_root: str | Path = "data",
                  tasks: tuple[str, ...] = ("binary", "multiclass"),
                  splits: tuple[str, ...] = ("train", "val", "test")) -> dict:

    data_root = Path(data_root)
    datasets  = {}

    for task in tasks:
        task_dir     = data_root / task
        task_dict    = {}

        for split in splits:
            split_dict = {}
            for kind in ("X", "y"):
                file_path = task_dir / f"{kind}_{split}.pkl"
                split_dict[kind] = pd.read_pickle(file_path)
            task_dict[split] = split_dict

        datasets[task] = task_dict

    return datasets

# %%
from typing import Tuple, Literal
import pandas as pd

def load_split(
    preprocessing_type: Literal["cleaned_only", "full_process"],
    sampling_method: Literal["undersampled", "oversampled"],
    classification_type: Literal["binary", "multiclass"]
) -> Tuple[
    Tuple[pd.DataFrame, pd.Series],  # train: (X_train, y_train)
    Tuple[pd.DataFrame, pd.Series],  # val: (X_val, y_val)
    Tuple[pd.DataFrame, pd.Series]   # test: (X_test, y_test)
]:
    """
    Load different types of splits from the data
    
    Args:
        preprocessing_type: must be "cleaned_only" or "full_process"
        sampling_method: must be "undersampled" or "oversampled"
        classification_type: must be "binary" or "multiclass"
    
    Returns:
        Tuple of (train, val, test) splits, where each split is (X, y)
        - train: (X_train, y_train)
        - val: (X_val, y_val)  
        - test: (X_test, y_test)
    """
    dataset = load_datasets(
        f"../data/{preprocessing_type}/{sampling_method}")[classification_type]
    split_names = ["train", "val", "test"]

    return tuple([(lambda split: (dataset[split]["X"], dataset[split]["y"]))(split) for split in split_names])

# %% [markdown]
# # Experiments

# %%
def combine_text(X):
    X = X.copy()

    combined = X["resume_text"].astype(
        str) + " [SEP] " + X["job_description_text"].astype(str)

    return combined.values

# %%
splits = load_split(preprocessing_type="cleaned_only", sampling_method="undersampled", classification_type="binary")

# %%
SEED = 42

# %% [markdown]
# ## Experiment 3: Feature Selection methods

# %% [markdown]
# ### Chi2 Squared Configurations
#
# Best for:
# - EBM Chi2: 100 @ 67.04%
# - Ridge Chi2: 100 @ 67.09%
# - LogReg Chi2: 100 @ 66.51%

# %%
from utils import ExperimentManager, Experiment

chi2_manager = ExperimentManager(f"../runs/ensembles/chi2/", ["Fit", "Not Fit"])

# %%
k_sizes = [10, 50, 100, 500, 1000, 5000]

# %%
from sklearn.feature_selection import chi2, SelectKBest

for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=ExplainableBoostingClassifier(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(chi2, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"EBM meta chi2 {size} stack",
        description=f"Stack ensemble classifier with EBM classifier and chi2 {size}",
        pipeline_factory=pipeline_factory
    )

    chi2_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: EBM meta chi2 10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5408
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5190
#    Micro F1:     0.5408
#    Weighted F1:  0.5190
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5499  R: 0.5408
#    Micro    - P: 0.5408  R: 0.5408
#    Weighted - P: 0.5499  R: 0.5408
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5286     0.7538     0.6215        857
#    Not Fit              0.5711     0.3279     0.4166        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5499     0.5408     0.5190       1714
#    weighted avg         0.5499     0.5408     0.5190       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           646      211
#    Not Fit       576      281
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 10 stack' completed and logged.
#
#
# === Running Experiment: EBM meta chi2 50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5834
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5816
#    Micro F1:     0.5834
#    Weighted F1:  0.5816
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5849  R: 0.5834
#    Micro    - P: 0.5834  R: 0.5834
#    Weighted - P: 0.5849  R: 0.5834
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5736     0.6499     0.6094        857
#    Not Fit              0.5962     0.5169     0.5537        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5849     0.5834     0.5816       1714
#    weighted avg         0.5849     0.5834     0.5816       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           557      300
#    Not Fit       414      443
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 50 stack' completed and logged.
#
#
# === Running Experiment: EBM meta chi2 100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6727
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6717
#    Micro F1:     0.6727
#    Weighted F1:  0.6717
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6748  R: 0.6727
#    Micro    - P: 0.6727  R: 0.6727
#    Weighted - P: 0.6748  R: 0.6727
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6555     0.7281     0.6899        857
#    Not Fit              0.6942     0.6173     0.6535        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6748     0.6727     0.6717       1714
#    weighted avg         0.6748     0.6727     0.6717       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           624      233
#    Not Fit       328      529
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 100 stack' completed and logged.
#
#
# === Running Experiment: EBM meta chi2 500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6505
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6505
#    Micro F1:     0.6505
#    Weighted F1:  0.6505
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6506  R: 0.6505
#    Micro    - P: 0.6505  R: 0.6505
#    Weighted - P: 0.6506  R: 0.6505
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6473     0.6616     0.6544        857
#    Not Fit              0.6539     0.6394     0.6466        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6506     0.6505     0.6505       1714
#    weighted avg         0.6506     0.6505     0.6505       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           567      290
#    Not Fit       309      548
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 500 stack' completed and logged.
#
#
# === Running Experiment: EBM meta chi2 1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6278
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6277
#    Micro F1:     0.6278
#    Weighted F1:  0.6277
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6278  R: 0.6278
#    Micro    - P: 0.6278  R: 0.6278
#    Weighted - P: 0.6278  R: 0.6278
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6308     0.6161     0.6234        857
#    Not Fit              0.6249     0.6394     0.6321        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6278     0.6278     0.6277       1714
#    weighted avg         0.6278     0.6278     0.6277       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           528      329
#    Not Fit       309      548
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 1000 stack' completed and logged.
#
#
# === Running Experiment: EBM meta chi2 5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6523
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6522
#    Micro F1:     0.6523
#    Weighted F1:  0.6522
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6525  R: 0.6523
#    Micro    - P: 0.6523  R: 0.6523
#    Weighted - P: 0.6525  R: 0.6523
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6468     0.6709     0.6586        857
#    Not Fit              0.6582     0.6336     0.6457        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6525     0.6523     0.6522       1714
#    weighted avg         0.6525     0.6523     0.6522       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           575      282
#    Not Fit       314      543
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta chi2 5000 stack' completed and logged.

# %%
for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=RidgeClassifier(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(chi2, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"ridge meta chi2 {size} stack",
        description=f"Stack ensemble classifier with ridge classifier and chi2 {size}",
        pipeline_factory=pipeline_factory
    )

    chi2_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: ridge meta chi2 10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5438
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5293
#    Micro F1:     0.5438
#    Weighted F1:  0.5293
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5499  R: 0.5438
#    Micro    - P: 0.5438  R: 0.5438
#    Weighted - P: 0.5499  R: 0.5438
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5324     0.7188     0.6117        857
#    Not Fit              0.5673     0.3687     0.4470        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5499     0.5438     0.5293       1714
#    weighted avg         0.5499     0.5438     0.5293       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           616      241
#    Not Fit       541      316
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 10 stack' completed and logged.
#
#
# === Running Experiment: ridge meta chi2 50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5840
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5836
#    Micro F1:     0.5840
#    Weighted F1:  0.5836
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5843  R: 0.5840
#    Micro    - P: 0.5840  R: 0.5840
#    Weighted - P: 0.5843  R: 0.5840
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5793     0.6138     0.5960        857
#    Not Fit              0.5893     0.5543     0.5713        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5843     0.5840     0.5836       1714
#    weighted avg         0.5843     0.5840     0.5836       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           526      331
#    Not Fit       382      475
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 50 stack' completed and logged.
#
#
# === Running Experiment: ridge meta chi2 100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6704
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6695
#    Micro F1:     0.6704
#    Weighted F1:  0.6695
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6722  R: 0.6704
#    Micro    - P: 0.6704  R: 0.6704
#    Weighted - P: 0.6722  R: 0.6704
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6543     0.7223     0.6866        857
#    Not Fit              0.6901     0.6184     0.6523        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6722     0.6704     0.6695       1714
#    weighted avg         0.6722     0.6704     0.6695       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           619      238
#    Not Fit       327      530
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 100 stack' completed and logged.
#
#
# === Running Experiment: ridge meta chi2 500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6499
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6496
#    Micro F1:     0.6499
#    Weighted F1:  0.6496
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6505  R: 0.6499
#    Micro    - P: 0.6499  R: 0.6499
#    Weighted - P: 0.6505  R: 0.6499
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6411     0.6814     0.6606        857
#    Not Fit              0.6600     0.6184     0.6386        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6505     0.6499     0.6496       1714
#    weighted avg         0.6505     0.6499     0.6496       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           584      273
#    Not Fit       327      530
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 500 stack' completed and logged.
#
#
# === Running Experiment: ridge meta chi2 1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6424
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6418
#    Micro F1:     0.6424
#    Weighted F1:  0.6418
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6432  R: 0.6424
#    Micro    - P: 0.6424  R: 0.6424
#    Weighted - P: 0.6432  R: 0.6424
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6323     0.6803     0.6554        857
#    Not Fit              0.6540     0.6044     0.6283        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6432     0.6424     0.6418       1714
#    weighted avg         0.6432     0.6424     0.6418       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           583      274
#    Not Fit       339      518
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 1000 stack' completed and logged.
#
#
# === Running Experiment: ridge meta chi2 5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6441
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6433
#    Micro F1:     0.6441
#    Weighted F1:  0.6433
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6455  R: 0.6441
#    Micro    - P: 0.6441  R: 0.6441
#    Weighted - P: 0.6455  R: 0.6441
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6312     0.6931     0.6607        857
#    Not Fit              0.6598     0.5951     0.6258        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6455     0.6441     0.6433       1714
#    weighted avg         0.6455     0.6441     0.6433       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           594      263
#    Not Fit       347      510
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta chi2 5000 stack' completed and logged.

# %%
for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=LogisticRegression(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(chi2, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"LogReg meta chi2 {size} stack",
        description=f"Stack ensemble classifier with LogReg classifier and chi2 {size}",
        pipeline_factory=pipeline_factory
    )

    chi2_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: LogReg meta chi2 10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5414
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5283
#    Micro F1:     0.5414
#    Weighted F1:  0.5283
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5466  R: 0.5414
#    Micro    - P: 0.5414  R: 0.5414
#    Weighted - P: 0.5466  R: 0.5414
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5311     0.7083     0.6070        857
#    Not Fit              0.5622     0.3746     0.4496        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5466     0.5414     0.5283       1714
#    weighted avg         0.5466     0.5414     0.5283       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           607      250
#    Not Fit       536      321
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 10 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta chi2 50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5858
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5855
#    Micro F1:     0.5858
#    Weighted F1:  0.5855
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5860  R: 0.5858
#    Micro    - P: 0.5858  R: 0.5858
#    Weighted - P: 0.5860  R: 0.5858
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5819     0.6091     0.5952        857
#    Not Fit              0.5900     0.5624     0.5759        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5860     0.5858     0.5855       1714
#    weighted avg         0.5860     0.5858     0.5855       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           522      335
#    Not Fit       375      482
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 50 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta chi2 100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6680
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6673
#    Micro F1:     0.6680
#    Weighted F1:  0.6673
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6695  R: 0.6680
#    Micro    - P: 0.6680  R: 0.6680
#    Weighted - P: 0.6695  R: 0.6680
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6535     0.7153     0.6830        857
#    Not Fit              0.6856     0.6208     0.6516        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6695     0.6680     0.6673       1714
#    weighted avg         0.6695     0.6680     0.6673       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           613      244
#    Not Fit       325      532
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 100 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta chi2 500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6523
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6521
#    Micro F1:     0.6523
#    Weighted F1:  0.6521
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6526  R: 0.6523
#    Micro    - P: 0.6523  R: 0.6523
#    Weighted - P: 0.6526  R: 0.6523
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6455     0.6756     0.6602        857
#    Not Fit              0.6597     0.6289     0.6440        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6526     0.6523     0.6521       1714
#    weighted avg         0.6526     0.6523     0.6521       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           579      278
#    Not Fit       318      539
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 500 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta chi2 1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6429
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6426
#    Micro F1:     0.6429
#    Weighted F1:  0.6426
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6436  R: 0.6429
#    Micro    - P: 0.6429  R: 0.6429
#    Weighted - P: 0.6436  R: 0.6429
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6342     0.6756     0.6542        857
#    Not Fit              0.6529     0.6103     0.6309        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6436     0.6429     0.6426       1714
#    weighted avg         0.6436     0.6429     0.6426       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           579      278
#    Not Fit       334      523
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 1000 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta chi2 5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6447
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6440
#    Micro F1:     0.6447
#    Weighted F1:  0.6440
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6459  R: 0.6447
#    Micro    - P: 0.6447  R: 0.6447
#    Weighted - P: 0.6459  R: 0.6447
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6328     0.6896     0.6600        857
#    Not Fit              0.6590     0.5998     0.6280        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6459     0.6447     0.6440       1714
#    weighted avg         0.6459     0.6447     0.6440       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           591      266
#    Not Fit       343      514
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta chi2 5000 stack' completed and logged.

# %%
chi2_manager.compare_experiments()

filename = "chi2_selector_comparisons.csv"
dir = "../experiment_summaries/ensemble"

chi2_manager.export_experiment_summary(dir, filename)
chi2_manager.close()
# Out:
# === Experiment Comparison (accuracy) ===
# Experiment                     Test Score   Status
# -------------------------------------------------------
# EBM meta chi2 10 stack         0.5408       ✅ Completed
# EBM meta chi2 50 stack         0.5834       ✅ Completed
# EBM meta chi2 100 stack        0.6727       ✅ Completed
# EBM meta chi2 500 stack        0.6505       ✅ Completed
# EBM meta chi2 1000 stack       0.6278       ✅ Completed
# EBM meta chi2 5000 stack       0.6523       ✅ Completed
# ridge meta chi2 10 stack       0.5438       ✅ Completed
# ridge meta chi2 50 stack       0.5840       ✅ Completed
# ridge meta chi2 100 stack      0.6704       ✅ Completed
# ridge meta chi2 500 stack      0.6499       ✅ Completed
# ridge meta chi2 1000 stack     0.6424       ✅ Completed
# ridge meta chi2 5000 stack     0.6441       ✅ Completed
# LogReg meta chi2 10 stack      0.5414       ✅ Completed
# LogReg meta chi2 50 stack      0.5858       ✅ Completed
# LogReg meta chi2 100 stack     0.6680       ✅ Completed
# LogReg meta chi2 500 stack     0.6523       ✅ Completed
# LogReg meta chi2 1000 stack    0.6429       ✅ Completed
# LogReg meta chi2 5000 stack    0.6447       ✅ Completed
# 📊 Experiment summary exported to: chi2_selector_comparisons.csv
