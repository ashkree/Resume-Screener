# %%
import sys
sys.path.append('..')

# %%
import warnings
import multiprocessing
warnings.filterwarnings("ignore", category=ResourceWarning)

# Also suppress multiprocessing warnings
import sys
import os
os.environ['PYTHONWARNINGS'] = 'ignore::ResourceWarning'

# %% [markdown]
# # Data Loading

# %%
from pathlib import Path
import pandas as pd

def load_datasets(data_root: str | Path = "data",
                  tasks: tuple[str, ...] = ("binary", "multiclass"),
                  splits: tuple[str, ...] = ("train", "val", "test")) -> dict:

    data_root = Path(data_root)
    datasets  = {}

    for task in tasks:
        task_dir     = data_root / task
        task_dict    = {}

        for split in splits:
            split_dict = {}
            for kind in ("X", "y"):
                file_path = task_dir / f"{kind}_{split}.pkl"
                split_dict[kind] = pd.read_pickle(file_path)
            task_dict[split] = split_dict

        datasets[task] = task_dict

    return datasets

# %%
from typing import Tuple, Literal
import pandas as pd

def load_split(
    preprocessing_type: Literal["cleaned_only", "full_process"],
    sampling_method: Literal["undersampled", "oversampled"],
    classification_type: Literal["binary", "multiclass"]
) -> Tuple[
    Tuple[pd.DataFrame, pd.Series],  # train: (X_train, y_train)
    Tuple[pd.DataFrame, pd.Series],  # val: (X_val, y_val)
    Tuple[pd.DataFrame, pd.Series]   # test: (X_test, y_test)
]:
    """
    Load different types of splits from the data
    
    Args:
        preprocessing_type: must be "cleaned_only" or "full_process"
        sampling_method: must be "undersampled" or "oversampled"
        classification_type: must be "binary" or "multiclass"
    
    Returns:
        Tuple of (train, val, test) splits, where each split is (X, y)
        - train: (X_train, y_train)
        - val: (X_val, y_val)  
        - test: (X_test, y_test)
    """
    dataset = load_datasets(
        f"../data/{preprocessing_type}/{sampling_method}")[classification_type]
    split_names = ["train", "val", "test"]

    return tuple([(lambda split: (dataset[split]["X"], dataset[split]["y"]))(split) for split in split_names])

# %% [markdown]
# # Experiments

# %%
def combine_text(X):
    X = X.copy()

    combined = X["resume_text"].astype(
        str) + " [SEP] " + X["job_description_text"].astype(str)

    return combined.values

# %%
splits = load_split(preprocessing_type="cleaned_only", sampling_method="undersampled", classification_type="binary")

# %%
SEED = 42

# %% [markdown]
# ## Experiment 3: Feature Selection methods

# %% [markdown]
# ### F-Test Configurations
#
# Best for:
# - EBM F-test 1000 @ 65.05%
# - Ridge F-test: 1000 @ 64.94%
# - LogReg F-test: 1000 @ 65.11%

# %%
from utils import ExperimentManager, Experiment

f_test_manager = ExperimentManager(f"../runs/ensembles/f-test/", ["Fit", "Not Fit"])

# %%
k_sizes = [10, 50, 100, 500, 1000, 5000]

# %%
from sklearn.feature_selection import f_classif

for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=ExplainableBoostingClassifier(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(f_classif, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"EBM meta f-test {size} stack",
        description=f"Stack ensemble classifier with EBM classifier and f-test {size}",
        pipeline_factory=pipeline_factory
    )

    f_test_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: EBM meta f-test 10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5210
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5013
#    Micro F1:     0.5210
#    Weighted F1:  0.5013
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5250  R: 0.5210
#    Micro    - P: 0.5210  R: 0.5210
#    Weighted - P: 0.5250  R: 0.5210
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5150     0.7200     0.6005        857
#    Not Fit              0.5349     0.3221     0.4020        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5250     0.5210     0.5013       1714
#    weighted avg         0.5250     0.5210     0.5013       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           617      240
#    Not Fit       581      276
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 10 stack' completed and logged.
#
#
# === Running Experiment: EBM meta f-test 50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5403
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5334
#    Micro F1:     0.5403
#    Weighted F1:  0.5334
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5428  R: 0.5403
#    Micro    - P: 0.5403  R: 0.5403
#    Weighted - P: 0.5428  R: 0.5403
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5324     0.6616     0.5900        857
#    Not Fit              0.5532     0.4189     0.4768        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5428     0.5403     0.5334       1714
#    weighted avg         0.5428     0.5403     0.5334       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           567      290
#    Not Fit       498      359
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 50 stack' completed and logged.
#
#
# === Running Experiment: EBM meta f-test 100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5898
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5893
#    Micro F1:     0.5898
#    Weighted F1:  0.5893
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5903  R: 0.5898
#    Micro    - P: 0.5898  R: 0.5898
#    Weighted - P: 0.5903  R: 0.5898
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5837     0.6266     0.6044        857
#    Not Fit              0.5970     0.5531     0.5742        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5903     0.5898     0.5893       1714
#    weighted avg         0.5903     0.5898     0.5893       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           537      320
#    Not Fit       383      474
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 100 stack' completed and logged.
#
#
# === Running Experiment: EBM meta f-test 500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6354
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6342
#    Micro F1:     0.6354
#    Weighted F1:  0.6342
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6371  R: 0.6354
#    Micro    - P: 0.6354  R: 0.6354
#    Weighted - P: 0.6371  R: 0.6354
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6526     0.5788     0.6135        857
#    Not Fit              0.6216     0.6919     0.6549        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6371     0.6354     0.6342       1714
#    weighted avg         0.6371     0.6354     0.6342       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           496      361
#    Not Fit       264      593
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 500 stack' completed and logged.
#
#
# === Running Experiment: EBM meta f-test 1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6406
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6405
#    Micro F1:     0.6406
#    Weighted F1:  0.6405
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6408  R: 0.6406
#    Micro    - P: 0.6406  R: 0.6406
#    Weighted - P: 0.6408  R: 0.6406
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6464     0.6208     0.6333        857
#    Not Fit              0.6352     0.6604     0.6476        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6408     0.6406     0.6405       1714
#    weighted avg         0.6408     0.6406     0.6405       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           532      325
#    Not Fit       291      566
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 1000 stack' completed and logged.
#
#
# === Running Experiment: EBM meta f-test 5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6459
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6456
#    Micro F1:     0.6459
#    Weighted F1:  0.6456
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6463  R: 0.6459
#    Micro    - P: 0.6459  R: 0.6459
#    Weighted - P: 0.6463  R: 0.6459
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6547     0.6173     0.6354        857
#    Not Fit              0.6380     0.6744     0.6557        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6463     0.6459     0.6456       1714
#    weighted avg         0.6463     0.6459     0.6456       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           529      328
#    Not Fit       279      578
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'EBM meta f-test 5000 stack' completed and logged.

# %%
for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=RidgeClassifier(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(f_classif, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"ridge meta f-test {size} stack",
        description=f"Stack ensemble classifier with ridge classifier and f-test {size}",
        pipeline_factory=pipeline_factory
    )

    f_test_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: ridge meta f-test 10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5152
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.4964
#    Micro F1:     0.5152
#    Weighted F1:  0.4964
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5178  R: 0.5152
#    Micro    - P: 0.5152  R: 0.5152
#    Weighted - P: 0.5178  R: 0.5152
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5109     0.7083     0.5936        857
#    Not Fit              0.5247     0.3221     0.3991        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5178     0.5152     0.4964       1714
#    weighted avg         0.5178     0.5152     0.4964       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           607      250
#    Not Fit       581      276
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 10 stack' completed and logged.
#
#
# === Running Experiment: ridge meta f-test 50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5333
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5311
#    Micro F1:     0.5333
#    Weighted F1:  0.5311
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5339  R: 0.5333
#    Micro    - P: 0.5333  R: 0.5333
#    Weighted - P: 0.5339  R: 0.5333
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5293     0.6009     0.5628        857
#    Not Fit              0.5385     0.4656     0.4994        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5339     0.5333     0.5311       1714
#    weighted avg         0.5339     0.5333     0.5311       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           515      342
#    Not Fit       458      399
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 50 stack' completed and logged.
#
#
# === Running Experiment: ridge meta f-test 100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5881
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5869
#    Micro F1:     0.5881
#    Weighted F1:  0.5869
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5892  R: 0.5881
#    Micro    - P: 0.5881  R: 0.5881
#    Weighted - P: 0.5892  R: 0.5881
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5794     0.6429     0.6095        857
#    Not Fit              0.5990     0.5333     0.5642        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5892     0.5881     0.5869       1714
#    weighted avg         0.5892     0.5881     0.5869       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           551      306
#    Not Fit       400      457
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 100 stack' completed and logged.
#
#
# === Running Experiment: ridge meta f-test 500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6301
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6300
#    Micro F1:     0.6301
#    Weighted F1:  0.6300
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6302  R: 0.6301
#    Micro    - P: 0.6301  R: 0.6301
#    Weighted - P: 0.6302  R: 0.6301
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6263     0.6453     0.6356        857
#    Not Fit              0.6342     0.6149     0.6244        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6302     0.6301     0.6300       1714
#    weighted avg         0.6302     0.6301     0.6300       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           553      304
#    Not Fit       330      527
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 500 stack' completed and logged.
#
#
# === Running Experiment: ridge meta f-test 1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6429
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6425
#    Micro F1:     0.6429
#    Weighted F1:  0.6425
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6436  R: 0.6429
#    Micro    - P: 0.6429  R: 0.6429
#    Weighted - P: 0.6436  R: 0.6429
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6339     0.6768     0.6546        857
#    Not Fit              0.6533     0.6091     0.6304        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6436     0.6429     0.6425       1714
#    weighted avg         0.6436     0.6429     0.6425       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           580      277
#    Not Fit       335      522
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 1000 stack' completed and logged.
#
#
# === Running Experiment: ridge meta f-test 5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6546
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6542
#    Micro F1:     0.6546
#    Weighted F1:  0.6542
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6554  R: 0.6546
#    Micro    - P: 0.6546  R: 0.6546
#    Weighted - P: 0.6554  R: 0.6546
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6442     0.6908     0.6667        857
#    Not Fit              0.6667     0.6184     0.6416        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6554     0.6546     0.6542       1714
#    weighted avg         0.6554     0.6546     0.6542       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           592      265
#    Not Fit       327      530
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'ridge meta f-test 5000 stack' completed and logged.

# %%
for size in k_sizes:

    def pipeline_factory(params):

        clf_lr = LogisticRegression(random_state=SEED)
        clf_rf = RandomForestClassifier(random_state=SEED)
        clf_nb = BernoulliNB()

        stacking_clf = StackingClassifier(
            estimators=[
                ('lr', clf_lr),
                ('nb', clf_nb),
                ('rf', clf_rf)
            ],
            final_estimator=LogisticRegression(random_state=SEED),
            cv=5,
            n_jobs=1
        )

        return Pipeline([
            ("join", FunctionTransformer(combine_text, validate=False)),
            ('tfidf', TfidfVectorizer()),  # Convert text to numeric
            ('selector', SelectKBest(f_classif, k=size)),
            ('clf', stacking_clf)
        ])
    
    experiment = Experiment(
        name=f"LogReg meta f-test{size} stack",
        description=f"Stack ensemble classifier with LogReg classifier and f-test{size}",
        pipeline_factory=pipeline_factory
    )

    f_test_manager.run_experiment(experiment, splits=splits)
# Out:
# === Running Experiment: LogReg meta f-test10 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5152
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.4954
#    Micro F1:     0.5152
#    Weighted F1:  0.4954
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5180  R: 0.5152
#    Micro    - P: 0.5152  R: 0.5152
#    Weighted - P: 0.5180  R: 0.5152
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5109     0.7130     0.5952        857
#    Not Fit              0.5251     0.3174     0.3956        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5180     0.5152     0.4954       1714
#    weighted avg         0.5180     0.5152     0.4954       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           611      246
#    Not Fit       585      272
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test10 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta f-test50 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5274
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5264
#    Micro F1:     0.5274
#    Weighted F1:  0.5264
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5277  R: 0.5274
#    Micro    - P: 0.5274  R: 0.5274
#    Weighted - P: 0.5277  R: 0.5274
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5251     0.5729     0.5480        857
#    Not Fit              0.5302     0.4819     0.5049        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5277     0.5274     0.5264       1714
#    weighted avg         0.5277     0.5274     0.5264       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           491      366
#    Not Fit       444      413
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test50 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta f-test100 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.5852
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.5842
#    Micro F1:     0.5852
#    Weighted F1:  0.5842
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.5860  R: 0.5852
#    Micro    - P: 0.5852  R: 0.5852
#    Weighted - P: 0.5860  R: 0.5852
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.5775     0.6348     0.6048        857
#    Not Fit              0.5946     0.5356     0.5635        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.5860     0.5852     0.5842       1714
#    weighted avg         0.5860     0.5852     0.5842       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           544      313
#    Not Fit       398      459
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test100 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta f-test500 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6295
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6295
#    Micro F1:     0.6295
#    Weighted F1:  0.6295
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6296  R: 0.6295
#    Micro    - P: 0.6295  R: 0.6295
#    Weighted - P: 0.6296  R: 0.6295
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6276     0.6371     0.6323        857
#    Not Fit              0.6315     0.6219     0.6267        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6296     0.6295     0.6295       1714
#    weighted avg         0.6296     0.6295     0.6295       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           546      311
#    Not Fit       324      533
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test500 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta f-test1000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6441
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6439
#    Micro F1:     0.6441
#    Weighted F1:  0.6439
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6445  R: 0.6441
#    Micro    - P: 0.6441  R: 0.6441
#    Weighted - P: 0.6445  R: 0.6441
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6368     0.6709     0.6534        857
#    Not Fit              0.6523     0.6173     0.6343        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6445     0.6441     0.6439       1714
#    weighted avg         0.6445     0.6441     0.6439       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           575      282
#    Not Fit       328      529
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test1000 stack' completed and logged.
#
#
# === Running Experiment: LogReg meta f-test5000 stack ===
#
# ============================================================
# 🎯 TEST SET EVALUATION RESULTS
# ============================================================
#
# 📊 OVERVIEW
#    Test Samples: 1,714
#    Classes: 2
#    Overall Accuracy: 0.6540
#
# 🎯 MAIN PERFORMANCE METRICS
#    Macro F1:     0.6536
#    Micro F1:     0.6540
#    Weighted F1:  0.6536
#
# 📈 PRECISION/RECALL SUMMARY
#    Macro    - P: 0.6547  R: 0.6540
#    Micro    - P: 0.6540  R: 0.6540
#    Weighted - P: 0.6547  R: 0.6540
#
# 📋 DETAILED CLASSIFICATION REPORT
#    Class             Precision     Recall   F1-Score    Support
#    ---------------- ---------- ---------- ---------- ----------
#    Fit                  0.6444     0.6873     0.6652        857
#    Not Fit              0.6650     0.6208     0.6421        857
#    ---------------- ---------- ---------- ---------- ----------
#    macro avg            0.6547     0.6540     0.6536       1714
#    weighted avg         0.6547     0.6540     0.6536       1714
#
# 🔢 CONFUSION MATRIX
#    Rows: True Labels, Columns: Predicted Labels
#    Predicted →
#    True ↓        Fit  Not Fit
#    Fit           589      268
#    Not Fit       325      532
#
# ============================================================
# 💾 Finalizing experiment...
#
# ✅ Experiment 'LogReg meta f-test5000 stack' completed and logged.

# %%
f_test_manager.compare_experiments()

filename = "f-test_selector_comparisons.csv"
dir = "../experiment_summaries/ensemble"

f_test_manager.export_experiment_summary(dir, filename)
f_test_manager.close()
# Out:
# === Experiment Comparison (accuracy) ===
# Experiment                     Test Score   Status
# -------------------------------------------------------
# EBM meta f-test 10 stack       0.5210       ✅ Completed
# EBM meta f-test 50 stack       0.5403       ✅ Completed
# EBM meta f-test 100 stack      0.5898       ✅ Completed
# EBM meta f-test 500 stack      0.6354       ✅ Completed
# EBM meta f-test 1000 stack     0.6406       ✅ Completed
# EBM meta f-test 5000 stack     0.6459       ✅ Completed
# ridge meta f-test 10 stack     0.5152       ✅ Completed
# ridge meta f-test 50 stack     0.5333       ✅ Completed
# ridge meta f-test 100 stack    0.5881       ✅ Completed
# ridge meta f-test 500 stack    0.6301       ✅ Completed
# ridge meta f-test 1000 stack   0.6429       ✅ Completed
# ridge meta f-test 5000 stack   0.6546       ✅ Completed
# LogReg meta f-test10 stack     0.5152       ✅ Completed
# LogReg meta f-test50 stack     0.5274       ✅ Completed
# LogReg meta f-test100 stack    0.5852       ✅ Completed
# LogReg meta f-test500 stack    0.6295       ✅ Completed
# LogReg meta f-test1000 stack   0.6441       ✅ Completed
# LogReg meta f-test5000 stack   0.6540       ✅ Completed
# 📊 Experiment summary exported to: f-test_selector_comparisons.csv
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa50d399da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7faf9ba91da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7eff8d9a1da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f8cf5a91da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fdb5ac91da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f48124a1da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7efd4a7adda0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f0149499da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f791c095da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f74b1e95da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f0c5fe95da0>
# Traceback (most recent call last):
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/home/maveron/.conda/envs/304/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
